# %%
# lets import the libraries
import selenium 
import pandas as pd

# %%
# !pip install webdriver-manager

from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# ...
# ====== WebDriver manager ======
# Current google-chrome version is 95.0.4638
# Get LATEST driver version for 95.0.4638
# Driver [C:\Users\user\.wdm\drivers\chromedriver\win32\95.0.4638.54\chromedriver.exe] found in cache

# %% [markdown]
# # Delhi to chennai

# %% [markdown]
# # airline name

# %%
# opening the link
url = "https://flight.yatra.com/air-search-ui/seodom/trigger?type=O&viewName=normal&flexi=0&noOfSegments=1&origin=DEL&originCountry=IN&destination=MAA&preferred=&destinationCountry=IN&flight_depart_date=25%2F11%2F2021&ADT=1&CHD=0&INF=0&class=Economy&source=seo"

# %%
driver.get(url)

# %%
# SCRAPPING airline_name
airline_name = driver.find_elements_by_xpath("//span[@class='i-b text ellipsis']")
airline_name
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="f44986f8-4f5c-4370-8f0e-887bb2eb7676")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="c2dd082a-0c06-4294-9322-e49663a30239")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="44a6eabd-2bad-4a3b-b053-7df3029aa754")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="ede34e69-5ab6-4351-9254-997201894679")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="bd59a26e-908a-4b31-a977-3419c660026d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="5eb612b4-ea31-4d43-b304-fda9b55f2c3f")>,
# ...

# %%
# looping the airline_name
Flight_name = []

for i in airline_name:
    Flight_name.append(i.text)
Flight_name
# Out:
# ['IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'SpiceJet',
#  'SpiceJet',
#  'Vistara',
#  'Vistara',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'Air India',
#  'Vistara',
#  'Vistara',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'SpiceJet',
#  'SpiceJet',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'SpiceJet',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'Air India',
#  'Go First',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Air India',
# ...

# %% [markdown]
# # Departure

# %%
#SCRAPPING departure
source = driver.find_elements_by_xpath("//p[@title='New Delhi']")
source
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="39930a4b-778b-4fe1-b752-4d6ec9927ae2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="abc0518b-59fe-4395-94d3-4cdb77011e99")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="e11d58c7-a82e-41c6-b73a-52d8faa70f64")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="ed26d0c6-7213-4dc9-a92a-21c70649581e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="009ebc8b-9a7b-45d9-9939-cd939204bf78")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="f0574f4b-3566-4284-b090-648302ad2413")>,
# ...

# %%
# looping the departure
Depart = []

for i in source:
    Depart.append(i.text)
Depart
# Out:
# ['New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
# ...

# %% [markdown]
# # destination

# %%
#SCRAPPING destination
destiny = driver.find_elements_by_xpath("//p[@title='Chennai']")
destiny
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="a24fd041-922f-4b0a-bf0d-db51d2251072")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="b479918b-1d1d-4140-b7c2-36875f04f56c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="f06ba5e9-b44c-4dcb-925b-ec96d54a2de7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="474ed0c0-180c-40ca-b867-946d50061225")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="69b9cf93-a4ad-4598-8363-50d9e9d1108c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="61af3cbb-4f48-4713-9168-00f51c3c0a24")>,
# ...

# %%
# looping the destination
Destination = []

for i in destiny:
    Destination.append(i.text)
Destination
# Out:
# ['Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
# ...

# %% [markdown]
# # departure time

# %%
#SCRAPPING departure time
Dept_Time = driver.find_elements_by_xpath("//div[@class='i-b pr']")
Dept_Time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="2b11a598-9ad4-433b-acc4-26c512fbbdb8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="1f181a0b-0aa1-4567-9211-dbede473ff56")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="fed8e337-3c1b-41c0-a918-a30e688122ec")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="c536460f-de40-4bdb-abf8-2d9de894296f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="e8a70325-e684-49a6-8f71-435e7fd86431")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="61e81e82-8b1f-4e86-9243-deb9d71555e5")>,
# ...

# %%
# looping the departure time
Departure_Time = []

for i in Dept_Time:
    Departure_Time.append(i.text)
Departure_Time
# Out:
# ['23:05',
#  '18:45',
#  '11:00',
#  '07:55',
#  '11:00',
#  '18:25',
#  '06:15',
#  '13:30',
#  '19:55',
#  '20:30',
#  '17:30',
#  '06:05',
#  '20:40',
#  '07:20',
#  '17:25',
#  '09:45',
#  '05:10',
#  '07:25',
#  '14:00',
#  '06:10',
#  '04:15',
#  '06:05',
#  '09:15',
#  '23:05',
#  '08:20',
#  '04:15',
#  '09:15',
#  '07:25',
#  '08:35',
#  '16:20',
#  '12:45',
#  '07:20',
#  '19:45',
#  '02:00',
#  '15:00',
#  '14:20',
#  '21:00',
#  '10:30',
#  '19:40',
#  '18:05',
#  '08:00',
#  '07:00',
#  '18:55',
#  '19:45',
#  '07:20',
#  '09:40',
#  '06:00',
#  '06:00',
#  '21:40',
#  '20:40',
#  '06:00',
#  '18:55',
#  '11:10',
#  '09:40',
#  '19:30',
#  '21:40',
#  '20:40',
#  '17:50',
#  '07:20',
#  '16:55',
#  '12:50',
#  '15:30',
#  '11:40',
#  '10:20',
#  '12:50',
#  '09:30',
#  '11:40',
#  '10:20',
#  '09:30',
#  '19:50',
#  '19:00',
#  '17:50',
#  '15:05',
#  '10:40',
#  '08:00',
#  '07:00',
#  '05:55',
#  '12:00',
#  '18:20',
#  '02:30',
#  '02:30',
#  '19:50',
#  '16:55',
# ...

# %% [markdown]
# # arrival time

# %%
#SCRAPPING arrival time
Arr_Time = driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
Arr_Time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="15b862bf-5794-4ad4-9c9f-4956d2a29778")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="cc7c9b3d-096b-4a73-992a-d0e747c87bf2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="d219320d-4fb8-4f7a-a668-523e8107699c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="9c3d3930-1d3e-453f-9305-34bfa2ddee9b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="ab67f15c-1a79-472f-803c-34a138d5a580")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="0cfa3885-5615-44bd-aa86-cdd10881902e")>,
# ...

# %%
# looping the arrival time
Arrival_Time = []

for i in Arr_Time:
    Arrival_Time.append(i.text)
Arrival_Time
# Out:
# ['01:55\n+ 1 day',
#  '21:45',
#  '17:40',
#  '15:05',
#  '18:50',
#  '21:10',
#  '09:10',
#  '16:20',
#  '22:45',
#  '23:20',
#  '20:25',
#  '08:55',
#  '23:35',
#  '10:10',
#  '20:15',
#  '12:40',
#  '10:05',
#  '12:25',
#  '19:20',
#  '12:00',
#  '10:25',
#  '12:25',
#  '15:55',
#  '05:55\n+ 1 day',
#  '15:55',
#  '12:00',
#  '17:00',
#  '10:10',
#  '11:25',
#  '19:10',
#  '15:40',
#  '21:20',
#  '21:20\n+ 1 day',
#  '07:40',
#  '22:20',
#  '22:20',
#  '07:40\n+ 1 day',
#  '22:20',
#  '07:40\n+ 1 day',
#  '07:40\n+ 1 day',
#  '22:20',
#  '22:20',
#  '21:20\n+ 1 day',
#  '08:00\n+ 1 day',
#  '08:00\n+ 1 day',
#  '17:40',
#  '11:50',
#  '19:55',
#  '11:50\n+ 1 day',
#  '11:50\n+ 1 day',
#  '23:05',
#  '08:00\n+ 1 day',
#  '16:30',
#  '15:05',
#  '00:25\n+ 1 day',
#  '09:05\n+ 1 day',
#  '09:05\n+ 1 day',
#  '10:55\n+ 1 day',
#  '17:10',
#  '23:05',
#  '19:55',
#  '23:05',
#  '19:55',
#  '19:55',
#  '23:05',
#  '19:55',
#  '23:05',
#  '23:05',
#  '23:05',
#  '11:50\n+ 1 day',
# ...

# %% [markdown]
# # duration

# %%
#SCRAPPING duration
Dur = driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
Dur
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="7fab431f-1a79-4d99-a3e7-6b9f4c798a8d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="c8c45217-c42e-4645-b5a6-9e9836709587")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="3a130904-af45-4aad-9b0c-00c3c6241fc4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="28973678-6a74-4597-a799-c6de5d3efcd5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="7726bb66-ce3e-4fb0-b18a-4f3dd006b84a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="5bf0cccc-173e-4b0e-aefa-6bff77cad24b")>,
# ...

# %%
# looping the duration
Duration = []

for i in Dur:
    Duration.append(i.text)
Duration
# Out:
# ['2h 50m',
#  '3h 00m',
#  '6h 40m',
#  '7h 10m',
#  '7h 50m',
#  '2h 45m',
#  '2h 55m',
#  '2h 50m',
#  '2h 50m',
#  '2h 50m',
#  '2h 55m',
#  '2h 50m',
#  '2h 55m',
#  '2h 50m',
#  '2h 50m',
#  '2h 55m',
#  '4h 55m',
#  '5h 00m',
#  '5h 20m',
#  '5h 50m',
#  '6h 10m',
#  '6h 20m',
#  '6h 40m',
#  '6h 50m',
#  '7h 35m',
#  '7h 45m',
#  '7h 45m',
#  '2h 45m',
#  '2h 50m',
#  '2h 50m',
#  '2h 55m',
#  '14h 00m',
#  '25h 35m',
#  '5h 40m',
#  '7h 20m',
#  '8h 00m',
#  '10h 40m',
#  '11h 50m',
#  '12h 00m',
#  '13h 35m',
#  '14h 20m',
#  '15h 20m',
#  '26h 25m',
#  '12h 15m',
#  '24h 40m',
#  '8h 00m',
#  '5h 50m',
#  '13h 55m',
#  '14h 10m',
#  '15h 10m',
#  '17h 05m',
#  '13h 05m',
#  '5h 20m',
#  '5h 25m',
#  '4h 55m',
#  '11h 25m',
#  '12h 25m',
#  '17h 05m',
#  '9h 50m',
#  '6h 10m',
#  '7h 05m',
#  '7h 35m',
#  '8h 15m',
#  '9h 35m',
#  '10h 15m',
#  '10h 25m',
#  '11h 25m',
#  '12h 45m',
#  '13h 35m',
#  '16h 00m',
#  '15h 55m',
#  '17h 05m',
#  '19h 50m',
#  '24h 15m',
# ...

# %% [markdown]
# # total stops

# %%
#SCRAPPING total stops
stops = driver.find_elements_by_xpath("//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']")
stops
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="0f407a07-4d5a-49c7-bd4a-5c5d32fd43ae")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="d1b99e0b-924c-4a03-b2a4-452498d87e1b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="70c20ba4-9c5b-46b1-9ef7-1f7ed6ddc69e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="f968ff78-6618-4cb6-a226-3a6656d60423")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="5854e560-f48d-4dd0-ac42-def6853eb778")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="a91ab2f2-da31-4581-809f-28ef5d0fc06c")>,
# ...

# %%
# looping the total stops
Total_stops = []

for i in stops:
    Total_stops.append(i.text)
Total_stops
# Out:
# ['Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
# ...

# %% [markdown]
# # Price

# %%
#SCRAPPING Price
cost = driver.find_elements_by_xpath("//div[@class='i-b tipsy fare-summary-tooltip fs-18']")
cost
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="8e32142d-1b10-4d7d-8d7e-568fa4aafd72")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="5643d46f-b898-4e94-b7cd-d087f394ac85")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="b868952e-c28d-45d4-a89d-0a58f1f61df7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="64c6bc33-20c8-4446-bfe2-9d0fd01c9e4c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="3e1f546d-5f21-424a-a8b4-bc603dbc7450")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="b85cdc43-e8a8-4ef5-b6f5-c6947a54909c")>,
# ...

# %%
# looping the Price
Price = []

for i in cost:
    Price.append(i.text)
Price
# Out:
# ['2,341',
#  '2,341',
#  '2,343',
#  '2,343',
#  '2,343',
#  '2,621',
#  '2,621',
#  '2,715',
#  '2,715',
#  '2,823',
#  '2,823',
#  '3,078',
#  '3,078',
#  '3,152',
#  '3,152',
#  '3,603',
#  '3,668',
#  '3,668',
#  '3,668',
#  '3,668',
#  '3,668',
#  '3,668',
#  '3,668',
#  '3,668',
#  '3,668',
#  '3,668',
#  '3,668',
#  '3,705',
#  '3,705',
#  '3,705',
#  '3,705',
#  '3,832',
#  '3,832',
#  '3,965',
#  '3,965',
#  '3,965',
#  '3,965',
#  '3,965',
#  '3,965',
#  '3,965',
#  '3,965',
#  '3,965',
#  '4,146',
#  '4,188',
#  '4,188',
#  '4,236',
#  '4,237',
#  '4,237',
#  '4,237',
#  '4,237',
#  '4,237',
#  '4,504',
#  '4,511',
#  '4,546',
#  '4,551',
#  '4,552',
#  '4,552',
#  '4,566',
#  '4,743',
#  '4,762',
#  '4,762',
#  '4,762',
#  '4,762',
#  '4,762',
#  '4,762',
#  '4,762',
#  '4,762',
#  '4,762',
#  '4,762',
#  '4,762',
#  '4,881',
#  '4,881',
#  '4,881',
#  '4,881',
#  '4,881',
#  '4,881',
#  '4,894',
#  '4,992',
#  '5,055',
#  '5,055',
#  '5,055',
#  '5,077',
#  '5,077',
# ...

# %%
# creating the dataframe for flight price prediction
df=pd.DataFrame({"Flight_name":Flight_name[0:],"Depart":Depart[0:],"Departure_Time":Departure_Time[0:],"Destination":Destination[0:],
                "Arrival_Time":Arrival_Time[0:],"Duration":Duration[0:],"Total_stops":Total_stops[0:],"Price":Price[0:]})
df
# Out:
#     Flight_name     Depart Departure_Time Destination    Arrival_Time  \
# 0        IndiGo  New Delhi          23:05     Chennai  01:55\n+ 1 day
# 1        IndiGo  New Delhi          18:45     Chennai           21:45
# 2        IndiGo  New Delhi          11:00     Chennai           17:40
# 3        IndiGo  New Delhi          07:55     Chennai           15:05
# 4        IndiGo  New Delhi          11:00     Chennai           18:50
# ..          ...        ...            ...         ...             ...
# 138     Vistara  New Delhi          14:15     Chennai           23:05
# 139    SpiceJet  New Delhi          11:55     Chennai           17:55
# 140   Air India  New Delhi          20:15     Chennai  10:40\n+ 1 day
# 141   Air India  New Delhi          16:55     Chennai  10:40\n+ 1 day
# 142   Air India  New Delhi          05:30     Chennai  10:40\n+ 1 day
#
#     Duration Total_stops   Price
# 0     2h 50m    Non Stop   2,341
# 1     3h 00m    Non Stop   2,341
# ...

# %%
df.to_csv("flightprice1",index=False)

# %% [markdown]
# # Delhi to Mumbai

# %% [markdown]
# # airline name

# %%
# opening the link
url = "https://flight.yatra.com/air-search-ui/seodom/trigger?type=O&viewName=normal&flexi=0&noOfSegments=1&origin=DEL&originCountry=IN&destination=BOM&preferred=&destinationCountry=IN&flight_depart_date=29%2F11%2F2021&ADT=1&CHD=0&INF=0&class=Economy&source=seo"

# %%
driver.get(url)

# %%
# SCRAPPING airline_name
airline_name = driver.find_elements_by_xpath("//span[@class='i-b text ellipsis']")
airline_name
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="e7976da5-e860-4c65-812d-7eaa6bf9273b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="715c9b90-3c23-452f-a5dd-d5b4c03fd6d7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="d40f4c43-3f9f-45cf-aac2-d4beb64876f7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="8284fb5a-c643-4191-9e1b-8d44e43d24ad")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="8f90bbab-c0a5-4edd-8859-01dda62abe75")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="c252c6e9-05a3-43f6-9ca5-5d73434facd1")>,
# ...

# %%
# looping the airline_name
Flight_name = []

for i in airline_name:
    Flight_name.append(i.text)
Flight_name
# Out:
# ['Air Asia',
#  'Go First',
#  'IndiGo',
#  'Go First',
#  'IndiGo',
#  'Go First',
#  'IndiGo',
#  'Go First',
#  'SpiceJet',
#  'IndiGo',
#  'Go First',
#  'IndiGo',
#  'Air Asia',
#  'Go First',
#  'SpiceJet',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'Air India',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'SpiceJet',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Air India',
#  'IndiGo',
#  'Air India',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'SpiceJet',
#  'Air India',
#  'Air India',
#  'Go First',
#  'Go First',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'IndiGo',
#  'Go First',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'SpiceJet',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'SpiceJet',
#  'Air India',
#  'Air India',
#  'Vistara',
#  'SpiceJet',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
# ...

# %% [markdown]
# # Departure

# %%
#SCRAPPING departure
source = driver.find_elements_by_xpath("//p[@title='New Delhi']")
source
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="479a99f1-460d-465a-8db9-576f8b714304")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="9c5b96bc-b4a6-461f-8437-214808d8dbd1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="a753dd49-fab7-4083-bd08-a4b95edafcc0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="03db71a5-8509-4fc8-8338-bf3f30cf93bd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="5bbbcd65-9867-40e8-be7d-6fcee5662b07")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="0af6f0c4-2f54-485d-bf27-545645892e0d")>,
# ...

# %%
# looping the departure
Depart = []

for i in source:
    Depart.append(i.text)
Depart
# Out:
# ['New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
# ...

# %% [markdown]
# # destination

# %%
#SCRAPPING destination
destiny = driver.find_elements_by_xpath("//p[@title='Mumbai']")
destiny
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="d29505c2-f675-4cc2-8b32-d3e76547b548")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="09527230-c1d8-4a24-910c-6005af71e52e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="2a07bca1-c219-4f38-a37f-88a3732fed06")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="2817679c-08fb-4356-bc84-e1c5702679c7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="8e91a068-7b51-4db5-955b-ebd82cd40ee8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="5f6f14f1-94c8-4d88-bf3a-ff4f76b297d3")>,
# ...

# %%
# looping the destination
Destination = []

for i in destiny:
    Destination.append(i.text)
Destination
# Out:
# ['Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
# ...

# %% [markdown]
# # departure time

# %%
#SCRAPPING departure time
Dept_Time = driver.find_elements_by_xpath("//div[@class='i-b pr']")
Dept_Time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="2ee41da9-cad4-4ded-adf9-91d7414cb6f4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="02c36761-d01b-4a67-936d-eae0e1ec1939")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="dd104da8-ac66-4e6f-9404-f892cf030c1c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="d56db47b-e544-4e52-a2a2-695494f3e605")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="44bb0f0c-b684-4e63-946e-e26379eea850")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="53ca4266-97c8-4f78-934e-9d12f4458ca6")>,
# ...

# %%
# looping the departure time
Departure_Time = []

for i in Dept_Time:
    Departure_Time.append(i.text)
Departure_Time
# Out:
# ['04:25',
#  '07:00',
#  '07:15',
#  '08:00',
#  '08:10',
#  '22:30',
#  '23:15',
#  '02:00',
#  '07:20',
#  '16:00',
#  '19:40',
#  '20:00',
#  '20:00',
#  '21:00',
#  '06:20',
#  '08:45',
#  '10:45',
#  '04:45',
#  '15:05',
#  '17:50',
#  '06:00',
#  '20:40',
#  '21:40',
#  '18:55',
#  '14:20',
#  '15:00',
#  '10:30',
#  '18:05',
#  '07:00',
#  '06:30',
#  '17:50',
#  '09:00',
#  '21:15',
#  '17:15',
#  '01:05',
#  '09:30',
#  '14:20',
#  '09:30',
#  '12:50',
#  '15:30',
#  '16:55',
#  '19:50',
#  '10:20',
#  '11:40',
#  '19:45',
#  '08:00',
#  '10:40',
#  '06:00',
#  '06:00',
#  '07:30',
#  '08:50',
#  '17:45',
#  '18:55',
#  '12:00',
#  '19:55',
#  '11:25',
#  '06:40',
#  '12:55',
#  '19:00',
#  '13:30',
#  '05:15',
#  '11:25',
#  '20:10',
#  '05:55',
#  '05:55',
#  '17:10',
#  '19:00',
#  '13:30',
#  '22:15',
#  '20:20',
#  '22:15',
#  '13:00',
#  '13:50',
#  '18:35',
#  '13:40',
#  '18:30',
#  '13:30',
#  '13:30',
#  '13:30',
#  '21:20',
#  '05:15',
#  '19:00',
#  '19:10',
# ...

# %% [markdown]
# ## arrival time

# %%
#SCRAPPING arrival time
Arr_Time = driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
Arr_Time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="3ae1d435-07c9-4a28-8d54-008d36b6dcc5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="9bad4d4d-65b4-44d6-b8b9-a275a8a331fe")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="81af8e5d-c009-4c50-9223-6cf39aa176dd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="1e7e11f0-8623-42a2-93e1-a3aaa4628835")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="3cb74869-7e5a-4f9f-b756-f6551a8347ff")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="33041c6f-5970-4f5e-9fb7-61ef27d30e57")>,
# ...

# %%
# looping the arrival time
Arrival_Time = []

for i in Arr_Time:
    Arrival_Time.append(i.text)
Arrival_Time
# Out:
# ['06:35',
#  '09:10',
#  '09:25',
#  '10:10',
#  '10:20',
#  '00:40\n+ 1 day',
#  '01:25\n+ 1 day',
#  '04:15',
#  '09:35',
#  '18:15',
#  '21:55',
#  '22:15',
#  '22:15',
#  '23:15',
#  '08:40',
#  '11:05',
#  '13:05',
#  '07:10',
#  '18:15',
#  '21:35',
#  '08:00',
#  '22:50',
#  '23:50',
#  '21:05',
#  '16:35',
#  '17:15',
#  '12:50',
#  '20:25',
#  '09:05',
#  '08:40',
#  '20:00',
#  '11:15',
#  '23:30',
#  '19:25',
#  '03:20',
#  '11:45',
#  '16:35',
#  '11:40',
#  '15:00',
#  '17:40',
#  '19:05',
#  '22:00',
#  '12:35',
#  '14:00',
#  '22:05',
#  '10:10',
#  '12:50',
#  '10:40',
#  '12:30',
#  '09:45',
#  '11:10',
#  '20:05',
#  '21:15',
#  '14:10',
#  '02:00\n+ 1 day',
#  '16:40',
#  '16:40',
#  '23:15',
#  '10:35\n+ 1 day',
#  '23:10',
#  '10:05',
#  '20:20',
#  '09:30\n+ 1 day',
#  '09:45',
#  '23:25',
#  '11:30\n+ 1 day',
#  '23:50',
#  '20:20',
#  '05:55\n+ 1 day',
#  '05:55\n+ 1 day',
#  '08:25\n+ 1 day',
#  '15:50\n+ 1 day',
#  '19:50',
#  '20:50',
#  '11:30\n+ 1 day',
# ...

# %% [markdown]
# # duration

# %%
#SCRAPPING duration
Dur = driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
Dur
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="ce25c170-a6e9-45d0-93ab-d45a494476ec")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="e254892f-58d5-40fb-8eb1-c22b9ce53bd5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="be1aa3bb-82ef-45bb-bb60-f810ee9b2b6e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="f4e6ee14-abdf-4b75-a970-397184380121")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="bad9207e-672a-4f80-93d8-acaa295aae6b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="364ba610-5ef5-448c-94a4-0e0f19394df2")>,
# ...

# %%
# looping the duration
Duration = []

for i in Dur:
    Duration.append(i.text)
Duration
# Out:
# ['2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 20m',
#  '2h 20m',
#  '2h 20m',
#  '2h 25m',
#  '3h 10m',
#  '3h 45m',
#  '2h 00m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 15m',
#  '2h 15m',
#  '2h 20m',
#  '2h 20m',
#  '2h 05m',
#  '2h 10m',
#  '2h 10m',
#  '2h 15m',
#  '2h 15m',
#  '2h 10m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 15m',
#  '2h 20m',
#  '2h 20m',
#  '2h 10m',
#  '2h 10m',
#  '4h 40m',
#  '6h 30m',
#  '2h 15m',
#  '2h 20m',
#  '2h 20m',
#  '2h 20m',
#  '2h 10m',
#  '6h 05m',
#  '5h 15m',
#  '10h 00m',
#  '10h 20m',
#  '15h 35m',
#  '9h 40m',
#  '4h 50m',
#  '8h 55m',
#  '13h 20m',
#  '3h 50m',
#  '17h 30m',
#  '18h 20m',
#  '4h 50m',
#  '6h 50m',
#  '7h 40m',
#  '9h 35m',
#  '10h 10m',
#  '26h 50m',
#  '6h 00m',
#  '2h 15m',
#  '21h 50m',
#  '4h 40m',
# ...

# %% [markdown]
# # total stops

# %%
#SCRAPPING total stops
stops = driver.find_elements_by_xpath("//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']")
stops
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="f2aa3ddc-163b-48c6-93d2-f59d54400036")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="57e306d1-da19-4b73-ac49-d30ea70795bd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="f0bdd899-5f5c-44ef-b742-e087c4176acd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="b88c75e4-4f3a-41eb-b5d4-d28678444b25")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="e3c6da14-5193-4494-bf4f-9836b9e1bc65")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="bfa2e7eb-326e-4268-9eec-e85fdf22344d")>,
# ...

# %%
# looping the total stops
Total_stops = []

for i in stops:
    Total_stops.append(i.text)
Total_stops
# Out:
# ['Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
# ...

# %% [markdown]
# # Price

# %%
#SCRAPPING Price
cost = driver.find_elements_by_xpath("//div[@class='i-b tipsy fare-summary-tooltip fs-18']")
cost
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="d391ca36-42dd-48b3-820c-c101f48dc38d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="7be08673-05bb-4e57-8bba-dbd4da4035d4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="4b4cdb1d-5dba-4db0-9e1a-28282fe2a217")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="cdf0af5e-a3e2-4004-b318-3c6f99de78c6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="3973fdd8-dd38-411d-b6b0-6dea1382220c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="9b0afcf7-f729-4906-bbed-9412fb808155")>,
# ...

# %%
# looping the Price
Price = []

for i in cost:
    Price.append(i.text)
Price
# Out:
# ['2,456',
#  '2,456',
#  '2,456',
#  '2,456',
#  '2,456',
#  '2,456',
#  '2,456',
#  '2,456',
#  '2,456',
#  '2,456',
#  '2,456',
#  '2,456',
#  '2,456',
#  '2,456',
#  '2,456',
#  '2,456',
#  '2,456',
#  '2,456',
#  '2,476',
#  '2,476',
#  '2,501',
#  '2,711',
#  '2,711',
#  '2,772',
#  '2,790',
#  '2,790',
#  '2,790',
#  '2,790',
#  '2,791',
#  '2,791',
#  '2,791',
#  '2,791',
#  '2,791',
#  '3,001',
#  '3,001',
#  '3,001',
#  '3,001',
#  '3,026',
#  '3,026',
#  '3,026',
#  '3,026',
#  '3,026',
#  '3,026',
#  '3,026',
#  '3,086',
#  '3,211',
#  '3,211',
#  '3,515',
#  '3,515',
#  '3,525',
#  '3,525',
#  '3,525',
#  '3,525',
#  '3,570',
#  '3,697',
#  '3,744',
#  '3,744',
#  '3,855',
#  '3,866',
#  '3,963',
#  '3,993',
#  '3,993',
#  '4,039',
#  '4,161',
#  '4,161',
#  '4,165',
#  '4,180',
#  '4,212',
#  '4,270',
#  '4,270',
#  '4,270',
#  '4,286',
#  '4,301',
#  '4,328',
#  '4,375',
#  '4,434',
#  '4,451',
#  '4,451',
#  '4,451',
#  '4,484',
#  '4,496',
#  '4,506',
#  '4,527',
# ...

# %%
# creating the dataframe for flight price prediction
df=pd.DataFrame({"Flight_name":Flight_name[0:],"Depart":Depart[0:],"Departure_Time":Departure_Time[0:],"Destination":Destination[0:],
                "Arrival_Time":Arrival_Time[0:],"Duration":Duration[0:],"Total_stops":Total_stops[0:],"Price":Price[0:]})
df
# Out:
#     Flight_name     Depart Departure_Time Destination Arrival_Time Duration  \
# 0      Air Asia  New Delhi          04:25      Mumbai        06:35   2h 10m
# 1      Go First  New Delhi          07:00      Mumbai        09:10   2h 10m
# 2        IndiGo  New Delhi          07:15      Mumbai        09:25   2h 10m
# 3      Go First  New Delhi          08:00      Mumbai        10:10   2h 10m
# 4        IndiGo  New Delhi          08:10      Mumbai        10:20   2h 10m
# ..          ...        ...            ...         ...          ...      ...
# 161    Go First  New Delhi          12:20      Mumbai        18:10   5h 50m
# 162    Go First  New Delhi          11:50      Mumbai        18:10   6h 20m
# 163    Go First  New Delhi          09:15      Mumbai        18:10   8h 55m
# 164    Go First  New Delhi          10:45      Mumbai        18:20   7h 35m
# 165      IndiGo  New Delhi          07:20      Mumbai        14:50   7h 30m
#
#     Total_stops   Price
# 0      Non Stop   2,456
# ...

# %%
df.to_csv("flightprice2",index=False)

# %% [markdown]
# # Delhi to Goa

# %% [markdown]
# # airline name

# %%
# opening the link
url = "https://flight.yatra.com/air-search-ui/seodom/trigger?type=O&viewName=normal&flexi=0&noOfSegments=1&origin=DEL&originCountry=IN&destination=GOI&preferred=&destinationCountry=IN&flight_depart_date=11%2F01%2F2022&ADT=1&CHD=0&INF=0&class=Economy&source=seo"

# %%
driver.get(url)

# %%
# SCRAPPING airline_name
airline_name = driver.find_elements_by_xpath("//span[@class='i-b text ellipsis']")
airline_name
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="2cb61c41-e194-44cc-acf7-71105b1c2374")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="f4a66910-d352-4770-87cc-f68109317d97")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="d0c06bf3-30d4-4ebb-b33d-ee688ae743b7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="22e55c55-9add-4c4e-9a2c-472237aeed46")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="0db0da7e-592f-46f8-8843-a8eebb7e39ef")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="6680fd89-14df-4829-abdc-31a8adb4b29d")>,
# ...

# %%
# looping the airline_name
Flight_name = []

for i in airline_name:
    Flight_name.append(i.text)
Flight_name
# Out:
# ['Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Go First',
#  'Air India',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Air India',
#  'Go First',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'Air India',
#  'Air India',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Air Asia',
#  'Air Asia',
#  'Go First',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Go First',
#  'Air Asia',
#  'IndiGo',
#  'SpiceJet',
#  'SpiceJet',
#  'IndiGo',
#  'IndiGo',
# ...

# %% [markdown]
# # departure

# %%
#SCRAPPING departure
source = driver.find_elements_by_xpath("//p[@title='New Delhi']")
source
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="2bef9de2-5170-42d0-8308-39c9c33fbee0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="98c8add5-e169-4c9f-af23-8bb6cc1533d1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="ef571ef8-c0af-4f0a-a6fd-a33d4c61786e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="c7db4b1f-942f-4ef9-9965-65e796735c2e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="0c028cd4-7e1b-4ca7-88e7-5a64e040d91c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="effc6ab1-a4a5-4b48-b412-990a6be3c4e5")>,
# ...

# %%
# looping the departure
Depart = []

for i in source:
    Depart.append(i.text)
Depart
# Out:
# ['New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
# ...

# %% [markdown]
# # destination

# %%
#SCRAPPING destination
destiny = driver.find_elements_by_xpath("//p[@title='Goa']")
destiny
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="43091967-c2e1-4807-9c7f-904765213af5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="89fc7818-adcc-4dac-91e1-d6ece60dfc2a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="25604c4f-2ae2-48cf-8b97-0bba2e536ba0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="09bcd6e7-d21c-4fb8-8630-fb57aab59d59")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="ae86c757-dee8-4de1-bfc0-b6ca255e732e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="525f5d0b-2376-4417-913f-a7b6c2a4ddb4")>,
# ...

# %%
# looping the destination
Destination = []

for i in destiny:
    Destination.append(i.text)
Destination
# Out:
# ['Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
# ...

# %% [markdown]
# # departure time

# %%
#SCRAPPING departure time
Dept_Time = driver.find_elements_by_xpath("//div[@class='i-b pr']")
Dept_Time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="495e94da-0d00-471b-830a-25ced918a452")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="eb0bb740-d94e-4d57-876d-da5ab76fe1ea")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="5a089061-6dc2-477e-b00f-413d67ff41f0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="889e5440-eedb-4dc2-99e5-4a4984bf1448")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="c78cb881-dd1c-483f-b269-ccdec8df4775")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="a9a18770-6105-48c0-bae0-115b359bab40")>,
# ...

# %%
# looping the departure time
Departure_Time = []

for i in Dept_Time:
    Departure_Time.append(i.text)
Departure_Time
# Out:
# ['22:00',
#  '15:05',
#  '20:00',
#  '19:00',
#  '10:40',
#  '17:50',
#  '17:50',
#  '08:00',
#  '07:00',
#  '15:05',
#  '20:00',
#  '19:00',
#  '10:40',
#  '17:50',
#  '17:50',
#  '08:00',
#  '07:00',
#  '18:05',
#  '15:05',
#  '22:30',
#  '15:00',
#  '14:20',
#  '21:00',
#  '10:40',
#  '19:40',
#  '08:00',
#  '07:00',
#  '20:00',
#  '19:00',
#  '08:45',
#  '08:00',
#  '10:30',
#  '08:00',
#  '07:00',
#  '10:55',
#  '07:20',
#  '19:45',
#  '10:35',
#  '15:50',
#  '06:05',
#  '18:50',
#  '08:30',
#  '07:20',
#  '15:50',
#  '06:05',
#  '10:35',
#  '08:00',
#  '07:00',
#  '10:30',
#  '10:30',
#  '08:00',
#  '07:00',
#  '08:00',
#  '05:20',
#  '20:00',
#  '20:35',
#  '12:10',
#  '19:10',
#  '00:05',
#  '10:45',
#  '12:40',
#  '22:05',
#  '19:30',
#  '17:55',
#  '09:30',
#  '07:15',
#  '20:55',
#  '17:45',
#  '06:30',
#  '05:30',
#  '08:45',
#  '06:00',
#  '21:40',
#  '20:40',
#  '12:00',
#  '11:10',
#  '18:40',
#  '12:10',
#  '16:00',
#  '07:15',
#  '16:45',
#  '15:45',
#  '11:25',
# ...

# %% [markdown]
# # arrival time

# %%
#SCRAPPING arrival time
Arr_Time = driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
Arr_Time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="1aa74b4d-39db-44bf-8223-ade6ea9a4c74")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="70797a04-5417-4805-b5e8-7a65167a4397")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="932b73d2-18d0-4761-9537-134be92d9e05")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="e1d3d373-bb44-40e9-bb39-7ef5bfb5d02c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="c69a0df5-5438-456f-aba8-f506018d1cf6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="a85e0ecb-8311-4510-8d66-ddc569ba5a6d")>,
# ...

# %%
# looping the arrival time
Arrival_Time = []

for i in Arr_Time:
    Arrival_Time.append(i.text)
Arrival_Time
# Out:
# ['00:35\n+ 1 day',
#  '22:35',
#  '06:50\n+ 1 day',
#  '06:50\n+ 1 day',
#  '22:35',
#  '06:50\n+ 1 day',
#  '06:50\n+ 1 day',
#  '22:35',
#  '22:35',
#  '06:50\n+ 1 day',
#  '14:45\n+ 1 day',
#  '14:45\n+ 1 day',
#  '06:50\n+ 1 day',
#  '14:45\n+ 1 day',
#  '14:45\n+ 1 day',
#  '06:50\n+ 1 day',
#  '06:50\n+ 1 day',
#  '23:25',
#  '20:30',
#  '06:10\n+ 1 day',
#  '23:25',
#  '23:25',
#  '06:10\n+ 1 day',
#  '20:30',
#  '06:10\n+ 1 day',
#  '20:30',
#  '20:30',
#  '20:30\n+ 1 day',
#  '20:30\n+ 1 day',
#  '15:25',
#  '15:25',
#  '18:00',
#  '14:45',
#  '14:45',
#  '13:15',
#  '12:50',
#  '01:55\n+ 1 day',
#  '17:05',
#  '22:25',
#  '12:50',
#  '01:55\n+ 1 day',
#  '17:05',
#  '17:05',
#  '01:55\n+ 1 day',
#  '17:05',
#  '22:25',
#  '12:45',
#  '12:45',
#  '16:30',
#  '17:45',
#  '16:30',
#  '16:30',
#  '17:45',
#  '07:50',
#  '22:35',
#  '23:10',
#  '14:50',
#  '21:50',
#  '02:50',
#  '13:30',
#  '15:25',
#  '00:50\n+ 1 day',
#  '22:00',
#  '20:35',
#  '15:25',
#  '15:25',
# ...

# %% [markdown]
# # duration

# %%
#SCRAPPING duration
Dur = driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
Dur
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="3c344196-25f6-44fa-a61f-8d19a53e6a5a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="f76db91a-9858-4444-bdbe-f9f2d5cb0c84")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="c805bfbd-f86a-4173-b601-d807c7ea9ad5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="f51a1b4b-78f4-4d5c-af84-4f9194d08cba")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="afa7a11d-c5c4-43e2-8d2d-7d84edcb82d0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="44b84364-d29c-4b3d-af10-91b830022f46")>,
# ...

# %%
# looping the duration
Duration = []

for i in Dur:
    Duration.append(i.text)
Duration
# Out:
# ['2h 35m',
#  '7h 30m',
#  '10h 50m',
#  '11h 50m',
#  '11h 55m',
#  '13h 00m',
#  '13h 00m',
#  '14h 35m',
#  '15h 35m',
#  '15h 45m',
#  '18h 45m',
#  '19h 45m',
#  '20h 10m',
#  '20h 55m',
#  '20h 55m',
#  '22h 50m',
#  '23h 50m',
#  '5h 20m',
#  '5h 25m',
#  '7h 40m',
#  '8h 25m',
#  '9h 05m',
#  '9h 10m',
#  '9h 50m',
#  '10h 30m',
#  '12h 30m',
#  '13h 30m',
#  '24h 30m',
#  '25h 30m',
#  '6h 40m',
#  '7h 25m',
#  '7h 30m',
#  '6h 45m',
#  '7h 45m',
#  '2h 20m',
#  '5h 30m',
#  '6h 10m',
#  '6h 30m',
#  '6h 35m',
#  '6h 45m',
#  '7h 05m',
#  '8h 35m',
#  '9h 45m',
#  '10h 05m',
#  '11h 00m',
#  '11h 50m',
#  '4h 45m',
#  '5h 45m',
#  '6h 00m',
#  '7h 15m',
#  '8h 30m',
#  '9h 30m',
#  '9h 45m',
#  '2h 30m',
#  '2h 35m',
#  '2h 35m',
#  '2h 40m',
#  '2h 40m',
#  '2h 45m',
#  '2h 45m',
#  '2h 45m',
#  '2h 45m',
#  '2h 30m',
#  '2h 40m',
#  '5h 55m',
#  '8h 10m',
#  '5h 00m',
#  '5h 05m',
#  '6h 05m',
#  '7h 05m',
#  '4h 45m',
#  '6h 45m',
#  '15h 05m',
#  '16h 05m',
#  '6h 00m',
# ...

# %% [markdown]
# # total stops

# %%
#SCRAPPING total stops
stops = driver.find_elements_by_xpath("//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']")
stops
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="5219d664-ef04-4727-816e-ae3287944a04")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="54f1991e-2d7b-4e2e-8d51-8fe47ed6b4fb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="b1966d48-4573-4a46-9d2b-730a77607d85")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="2dd4a41a-f9b0-47a4-8bfd-64d95c33acd3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="291b550f-38d0-47f2-aac4-22e57e949e64")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="04125832-b39d-48e5-83b8-9d82fd2f8493")>,
# ...

# %%
# looping the total stops
Total_stops = []

for i in stops:
    Total_stops.append(i.text)
Total_stops
# Out:
# ['Non Stop',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
# ...

# %% [markdown]
# # Price

# %%
#SCRAPPING Price
cost = driver.find_elements_by_xpath("//div[@class='i-b tipsy fare-summary-tooltip fs-18']")
cost
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="816178b7-4ea2-4969-ae38-68785a875ad9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="b08a53c7-c29e-439a-a286-84a2317161e7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="01ed7772-f30b-46fa-934d-2dced1d5efdd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="642d6c5b-827a-4c31-8dfe-15c12c511c46")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="362a860f-fe35-4e50-b6a8-37d61710fd49")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1cba313ea624d385c7d567bbaa84af28", element="7558a99c-2399-42de-8b72-304d738ca69d")>,
# ...

# %%
# looping the Price
Price = []

for i in cost:
    Price.append(i.text)
Price
# Out:
# ['3,563',
#  '3,988',
#  '3,988',
#  '3,988',
#  '3,988',
#  '3,988',
#  '3,988',
#  '3,988',
#  '3,988',
#  '3,988',
#  '3,988',
#  '3,988',
#  '3,988',
#  '3,988',
#  '3,988',
#  '3,988',
#  '3,988',
#  '4,116',
#  '4,116',
#  '4,116',
#  '4,116',
#  '4,116',
#  '4,116',
#  '4,116',
#  '4,116',
#  '4,116',
#  '4,116',
#  '4,116',
#  '4,116',
#  '4,238',
#  '4,238',
#  '4,238',
#  '4,303',
#  '4,303',
#  '4,311',
#  '4,326',
#  '4,326',
#  '4,326',
#  '4,326',
#  '4,326',
#  '4,326',
#  '4,326',
#  '4,326',
#  '4,326',
#  '4,326',
#  '4,326',
#  '4,360',
#  '4,360',
#  '4,360',
#  '4,360',
#  '4,360',
#  '4,360',
#  '4,360',
#  '4,500',
#  '4,500',
#  '4,500',
#  '4,500',
#  '4,500',
#  '4,500',
#  '4,500',
#  '4,500',
#  '4,500',
#  '4,502',
#  '4,502',
#  '4,626',
#  '4,626',
#  '4,640',
#  '4,661',
#  '4,661',
#  '4,661',
#  '4,723',
#  '4,823',
#  '4,823',
#  '4,823',
#  '4,836',
#  '4,923',
#  '4,923',
#  '4,945',
#  '4,947',
#  '5,049',
#  '5,049',
#  '5,049',
#  '5,132',
# ...

# %%
# creating the dataframe for flight price prediction
df=pd.DataFrame({"Flight_name":Flight_name[0:],"Depart":Depart[0:],"Departure_Time":Departure_Time[0:],"Destination":Destination[0:],
                "Arrival_Time":Arrival_Time[0:],"Duration":Duration[0:],"Total_stops":Total_stops[0:],"Price":Price[0:]})
df
# Out:
#     Flight_name     Depart Departure_Time Destination    Arrival_Time  \
# 0     Air India  New Delhi          22:00         Goa  00:35\n+ 1 day
# 1     Air India  New Delhi          15:05         Goa           22:35
# 2     Air India  New Delhi          20:00         Goa  06:50\n+ 1 day
# 3     Air India  New Delhi          19:00         Goa  06:50\n+ 1 day
# 4     Air India  New Delhi          10:40         Goa           22:35
# ..          ...        ...            ...         ...             ...
# 142   Air India  New Delhi          09:45         Goa           17:00
# 143   Air India  New Delhi          08:10         Goa           17:00
# 144   Air India  New Delhi          21:10         Goa  17:00\n+ 1 day
# 145     Vistara  New Delhi          20:35         Goa  12:45\n+ 1 day
# 146     Vistara  New Delhi          17:40         Goa  12:45\n+ 1 day
#
#     Duration Total_stops   Price
# 0     2h 35m    Non Stop   3,563
# 1     7h 30m   2 Stop(s)   3,988
# ...

# %%
df.to_csv("flightprice3",index=False)

# %% [markdown]
# # Delhi to Hyderabad

# %% [markdown]
# # airline name

# %%
# opening the link
url = "https://flight.yatra.com/air-search-ui/seodom/trigger?type=O&viewName=normal&flexi=0&noOfSegments=1&origin=DEL&originCountry=IN&destination=HYD&preferred=&destinationCountry=IN&flight_depart_date=06%2F01%2F2022&ADT=1&CHD=0&INF=0&class=Economy&source=seo"

# %%
driver.get(url)

# %%
# SCRAPPING airline name
airline_name = driver.find_elements_by_xpath("//span[@class='i-b text ellipsis']")
airline_name
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="a1ac0a89-844d-4591-bd1a-53ce273debf4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="f34ecf8c-07b7-4ff2-b931-800e9f915a7e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="06e90c9e-7c8f-42dc-8c24-4ad7b261d6ac")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="1a69fe6a-2fc0-42da-a28d-6e10718ee73c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="65212270-7952-44b3-84b5-a6150f3403e4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="30412e7f-cfd1-4310-ab3c-4c557479cbe5")>,
# ...

# %%
# looping the airline_name
Flight_name = []

for i in airline_name:
    Flight_name.append(i.text)
Flight_name
# Out:
# ['Air India',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air Asia',
#  'SpiceJet',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Go First',
#  'Go First',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'IndiGo',
#  'Air India',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Air India',
#  'Go First',
#  'Air India',
#  'Air India',
#  'Go First',
#  'Go First',
#  'Go First',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Go First',
#  'Go First',
#  'Vistara',
#  'Vistara',
# ...

# %% [markdown]
# # departure

# %%
#SCRAPPING departure
source = driver.find_elements_by_xpath("//p[@title='New Delhi']")
source
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="e067b01f-d800-4427-83ca-8ac12f0539d1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="1fec835d-19db-43c9-ab6d-403a898c7c80")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="0fb3f468-536c-4498-b23f-c9254ae2ffcc")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="9bb61ff1-1b86-4e3c-a1c5-d5e0d3d4a34a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="3362cf38-7085-4591-80a9-3dbfed23d2f4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="19541841-9d30-481c-a166-a27c7931bebb")>,
# ...

# %%
# looping the departure
Depart = []

for i in source:
    Depart.append(i.text)
Depart
# Out:
# ['New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
# ...

# %% [markdown]
# # destination

# %%
#SCRAPPING destination
destiny = driver.find_elements_by_xpath("//p[@title='Hyderabad']")
destiny
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="af716efb-8d6f-40b3-853c-feab2c7861c9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="d4b7a9a5-7d61-41b7-bf24-89344bb7b567")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="4517773c-4509-4aae-b9e2-423f5576d9ac")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="b7fcf5bc-93d3-4e39-89e6-1c6414288ae3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="16b67bca-d6f3-46cd-94b8-a73640ae2ad1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="bd4168e5-0918-49ab-b7a8-5ebc195a1279")>,
# ...

# %%
# looping the destination
Destination = []

for i in destiny:
    Destination.append(i.text)
Destination
# Out:
# ['Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
# ...

# %% [markdown]
# # departure time

# %%
#SCRAPPING departure time
Dept_Time = driver.find_elements_by_xpath("//div[@class='i-b pr']")
Dept_Time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="bb95e99c-4a92-4ff2-a6f5-7946e0202be2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="16a871a3-9a2c-4d06-a87d-6aa03b958a80")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="ccb4d5b2-92d4-4863-882c-5fa5149abb2d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="6ad263b7-6ba5-4db5-89b4-509defd56758")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="7351ea34-5578-4627-8357-a1b2ac1a60c2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="b58798f4-becb-4f44-a1a0-55d15ee3e278")>,
# ...

# %%
# looping the departure time
Departure_Time = []

for i in Dept_Time:
    Departure_Time.append(i.text)
Departure_Time
# Out:
# ['08:10',
#  '21:10',
#  '07:00',
#  '20:45',
#  '09:45',
#  '11:35',
#  '23:05',
#  '08:40',
#  '16:15',
#  '17:00',
#  '13:50',
#  '17:25',
#  '19:00',
#  '07:20',
#  '19:35',
#  '12:10',
#  '20:40',
#  '06:05',
#  '20:00',
#  '19:00',
#  '17:50',
#  '22:10',
#  '09:45',
#  '17:40',
#  '14:45',
#  '07:05',
#  '20:35',
#  '06:50',
#  '16:40',
#  '06:10',
#  '16:55',
#  '19:55',
#  '18:30',
#  '16:35',
#  '13:45',
#  '06:40',
#  '13:30',
#  '06:40',
#  '09:50',
#  '13:50',
#  '06:40',
#  '12:30',
#  '05:50',
#  '18:40',
#  '18:40',
#  '21:00',
#  '09:35',
#  '08:00',
#  '09:35',
#  '21:25',
#  '20:15',
#  '09:45',
#  '21:15',
#  '17:20',
#  '14:15',
#  '08:05',
#  '06:15',
#  '20:40',
#  '19:50',
#  '17:35',
#  '08:40',
#  '08:40',
#  '05:15',
#  '16:45',
#  '09:00',
#  '06:00',
#  '06:00',
#  '21:40',
#  '20:40',
#  '21:40',
#  '06:00',
#  '20:40',
#  '16:35',
#  '21:20',
#  '20:10',
#  '13:15',
#  '18:30',
#  '16:35',
#  '15:30',
#  '12:50',
#  '11:40',
#  '10:20',
#  '09:30',
# ...

# %% [markdown]
# # arrival time

# %%
#SCRAPPING arrival time
Arr_Time = driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
Arr_Time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="ebb6a3aa-81be-4c75-b98c-01d4445ee0ff")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="c4b3a964-506a-481d-bf96-a9aff679223f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="b3f061a2-24fb-4aea-9558-5a0d89a673c1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="9a3ac104-26ce-4c68-8b98-d61287318f33")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="fc0f545d-75cd-4952-bf68-4077eed810d7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="8f5ab410-67b1-454d-9f01-db7dea4d0126")>,
# ...

# %%
# looping the arrival time
Arrival_Time = []

for i in Arr_Time:
    Arrival_Time.append(i.text)
Arrival_Time
# Out:
# ['10:30',
#  '23:35',
#  '09:20',
#  '23:10',
#  '11:55',
#  '13:50',
#  '01:20\n+ 1 day',
#  '11:00',
#  '20:25',
#  '19:05',
#  '16:05',
#  '19:40',
#  '21:15',
#  '09:30',
#  '21:50',
#  '21:15',
#  '09:55\n+ 1 day',
#  '09:55\n+ 1 day',
#  '21:35\n+ 1 day',
#  '21:35\n+ 1 day',
#  '21:35\n+ 1 day',
#  '08:15\n+ 1 day',
#  '09:55\n+ 1 day',
#  '19:50',
#  '17:00',
#  '09:25',
#  '22:55',
#  '21:15',
#  '21:45',
#  '20:15',
#  '21:15\n+ 1 day',
#  '07:40\n+ 1 day',
#  '07:40\n+ 1 day',
#  '07:40\n+ 1 day',
#  '18:10',
#  '13:45',
#  '20:15',
#  '11:40',
#  '16:10',
#  '22:45',
#  '16:10',
#  '20:35',
#  '15:40',
#  '00:05\n+ 1 day',
#  '08:30\n+ 1 day',
#  '06:45\n+ 1 day',
#  '15:35',
#  '15:35',
#  '17:45',
#  '06:35\n+ 1 day',
#  '21:15\n+ 1 day',
#  '20:15',
#  '20:15\n+ 1 day',
#  '20:15\n+ 1 day',
#  '20:25',
#  '20:25',
#  '20:25',
#  '20:25\n+ 1 day',
#  '20:25\n+ 1 day',
#  '20:25\n+ 1 day',
#  '21:35\n+ 1 day',
#  '21:35\n+ 1 day',
#  '17:35',
#  '17:35\n+ 1 day',
# ...

# %% [markdown]
# ## duration

# %%
#SCRAPPING duration
Dur = driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
Dur
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="b4fe3c85-d71a-486a-ae9b-2f892dbaaf6c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="b887ec01-d721-4e5d-b6cd-876e4d4cddd6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="72638f44-5cbc-4262-89e4-7e60d4e7410c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="cc979cd3-c872-499d-9b23-8466728a7024")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="2863c38a-5336-49fb-a6ab-e04a0b0ded42")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="eec5019f-cdd3-46f4-a1e8-c278bed1f268")>,
# ...

# %%
# looping the duration
Duration = []

for i in Dur:
    Duration.append(i.text)
Duration
# Out:
# ['2h 20m',
#  '2h 25m',
#  '2h 20m',
#  '2h 25m',
#  '2h 10m',
#  '2h 15m',
#  '2h 15m',
#  '2h 20m',
#  '4h 10m',
#  '2h 05m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 10m',
#  '2h 15m',
#  '9h 05m',
#  '13h 15m',
#  '27h 50m',
#  '25h 35m',
#  '26h 35m',
#  '27h 45m',
#  '10h 05m',
#  '24h 10m',
#  '2h 10m',
#  '2h 15m',
#  '2h 20m',
#  '2h 20m',
#  '14h 25m',
#  '5h 05m',
#  '14h 05m',
#  '28h 20m',
#  '11h 45m',
#  '13h 10m',
#  '15h 05m',
#  '4h 25m',
#  '7h 05m',
#  '6h 45m',
#  '5h 00m',
#  '6h 20m',
#  '8h 55m',
#  '9h 30m',
#  '8h 05m',
#  '9h 50m',
#  '5h 25m',
#  '13h 50m',
#  '9h 45m',
#  '6h 00m',
#  '7h 35m',
#  '8h 10m',
#  '9h 10m',
#  '25h 00m',
#  '10h 30m',
#  '23h 00m',
#  '26h 55m',
#  '6h 10m',
#  '12h 20m',
#  '14h 10m',
#  '23h 45m',
#  '24h 35m',
#  '26h 50m',
#  '36h 55m',
#  '36h 55m',
#  '12h 20m',
#  '24h 50m',
#  '6h 30m',
#  '9h 30m',
#  '6h 15m',
#  '10h 10m',
#  '11h 10m',
#  '14h 35m',
#  '14h 55m',
#  '15h 35m',
#  '4h 55m',
#  '6h 20m',
# ...

# %% [markdown]
# # total stops

# %%
#SCRAPPING total stops
stops = driver.find_elements_by_xpath("//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']")
stops
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="a9b38b58-4aac-487f-9e30-faaddc5f7be1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="774628a0-b6ed-41fd-903a-4d793bf34b6d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="1c6bbfa5-0325-4e8f-b72b-9c0d4ec10a74")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="0e69caaf-09ef-4274-a175-f8ecf60d962c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="7551673b-23d4-480f-9d93-242104a8c1cb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="3f71a5f2-358e-4fec-9195-9a0c673f7f39")>,
# ...

# %%
# looping the total stops
Total_stops = []

for i in stops:
    Total_stops.append(i.text)
Total_stops
# Out:
# ['Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
# ...

# %% [markdown]
# # Price

# %%
#SCRAPPING Price
cost = driver.find_elements_by_xpath("//div[@class='i-b tipsy fare-summary-tooltip fs-18']")
cost
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="46b1a39f-cd17-408e-bfd5-e7ecc334b5e0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="c45f736b-9c16-4d3e-bb92-d648dec614ec")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="d6169e1f-690b-4896-8d42-98f0654998e4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="193cf4a0-d2b3-4b13-8d26-8c4e30ba625f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="8a26910c-e9e8-4844-badd-d864ee8cb3fe")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="3f401a34-b6f3-4d1d-8db1-c21a919d028d")>,
# ...

# %%
# looping the Price
Price = []

for i in cost:
    Price.append(i.text)
Price
# Out:
# ['2,098',
#  '2,098',
#  '2,510',
#  '2,510',
#  '2,518',
#  '2,720',
#  '2,720',
#  '2,720',
#  '3,120',
#  '3,199',
#  '3,435',
#  '3,435',
#  '3,435',
#  '3,499',
#  '3,499',
#  '3,994',
#  '4,076',
#  '4,076',
#  '4,209',
#  '4,209',
#  '4,209',
#  '4,352',
#  '4,391',
#  '4,412',
#  '4,412',
#  '4,412',
#  '4,412',
#  '4,415',
#  '4,571',
#  '4,903',
#  '4,940',
#  '5,075',
#  '5,075',
#  '5,075',
#  '5,177',
#  '5,177',
#  '5,215',
#  '5,294',
#  '5,294',
#  '5,294',
#  '5,294',
#  '5,397',
#  '5,406',
#  '5,440',
#  '5,440',
#  '5,464',
#  '5,466',
#  '5,466',
#  '5,466',
#  '5,466',
#  '5,609',
#  '5,740',
#  '5,740',
#  '5,740',
#  '5,754',
#  '5,754',
#  '5,754',
#  '5,754',
#  '5,754',
#  '5,754',
#  '5,893',
#  '5,893',
#  '5,989',
#  '5,989',
#  '6,258',
#  '6,258',
#  '6,806',
#  '6,806',
#  '6,806',
#  '6,806',
#  '6,806',
#  '6,806',
#  '6,988',
#  '6,988',
#  '6,988',
#  '6,988',
#  '6,988',
#  '6,988',
#  '7,142',
#  '7,142',
#  '7,142',
#  '7,142',
#  '7,142',
# ...

# %%
# creating the dataframe for flight price prediction
df=pd.DataFrame({"Flight_name":Flight_name[0:],"Depart":Depart[0:],"Departure_Time":Departure_Time[0:],"Destination":Destination[0:],
                "Arrival_Time":Arrival_Time[0:],"Duration":Duration[0:],"Total_stops":Total_stops[0:],"Price":Price[0:]})
df
# Out:
#     Flight_name     Depart Departure_Time Destination    Arrival_Time  \
# 0     Air India  New Delhi          08:10   Hyderabad           10:30
# 1     Air India  New Delhi          21:10   Hyderabad           23:35
# 2        IndiGo  New Delhi          07:00   Hyderabad           09:20
# 3        IndiGo  New Delhi          20:45   Hyderabad           23:10
# 4     Air India  New Delhi          09:45   Hyderabad           11:55
# ..          ...        ...            ...         ...             ...
# 110    Air Asia  New Delhi          12:40   Hyderabad           19:15
# 111   Air India  New Delhi          22:00   Hyderabad  21:05\n+ 1 day
# 112    Go First  New Delhi          10:45   Hyderabad           23:20
# 113    Air Asia  New Delhi          12:40   Hyderabad           21:25
# 114   Air India  New Delhi          10:55   Hyderabad           21:05
#
#     Duration Total_stops   Price
# 0     2h 20m    Non Stop   2,098
# 1     2h 25m    Non Stop   2,098
# ...

# %%
df.to_csv("flightprice4",index=False)

# %% [markdown]
# # Mumbai to Varanasi

# %% [markdown]
# # airline name

# %%
# opening the link
url = "https://flight.yatra.com/air-search-ui/seodom/trigger?type=O&viewName=normal&flexi=0&noOfSegments=1&origin=BOM&originCountry=IN&destination=VNS&preferred=&destinationCountry=IN&flight_depart_date=16%2F12%2F2021&ADT=1&CHD=0&INF=0&class=Economy&source=seo"

# %%
driver.get(url)

# %%
# SCRAPPING airline name
airline_name = driver.find_elements_by_xpath("//span[@class='i-b text ellipsis']")
airline_name
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="74f0bf60-a60b-481a-92fb-73dd56a09895")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="118975c1-d372-4603-a9ca-4c952f4459bb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="0c1f941b-69be-4a54-a659-af58b4fe0684")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="e894fba1-a4df-44ce-8306-847b0f4c3437")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="60a22557-44f5-4d61-809d-29180b14a4ea")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="5fc4ce47-9ddd-4d54-be45-7421de67d8f2")>,
# ...

# %%
# looping the airline_name
Flight_name = []

for i in airline_name:
    Flight_name.append(i.text)
Flight_name
# Out:
# ['SpiceJet',
#  'IndiGo',
#  'Go First',
#  'Air India',
#  'Vistara',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Air India',
#  'Air India',
#  'SpiceJet',
#  'SpiceJet',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Go First',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Air India',
#  'IndiGo',
#  'Go First',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Go First',
#  'Go First',
#  'Vistara',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Go First',
#  'Vistara',
#  'Vistara',
#  'Vistara',
# ...

# %% [markdown]
# # departure

# %%
#SCRAPPING departure
source = driver.find_elements_by_xpath("//p[@title='Mumbai']")
source
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="fcca6c28-756f-4838-8e26-905d9889f94b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="a2714881-065e-4229-950c-6c5a992c8d11")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="95ff1a58-a791-4c4a-a227-e4ff1df685cd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="38dabdcc-ba0d-4062-9307-d853495fd3a7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="61043bc3-69c8-4c2e-97bf-3a07c061eee8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="3a2a4ac4-4677-44b4-b404-15ae0192240c")>,
# ...

# %%
# looping the departure
Depart = []

for i in source:
    Depart.append(i.text)
Depart
# Out:
# ['Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
# ...

# %% [markdown]
# # destination

# %%
#SCRAPPING destination
destiny = driver.find_elements_by_xpath("//p[@title='Varanasi']")
destiny
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="379cfeb3-9780-45bb-be23-9b4958e3a7e9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="84ffedc7-6bc3-48bf-b425-98079f66cf16")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="e3bcb60f-f6a2-4f77-9d01-697d067a483b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="6a5a5761-267a-41d9-b90f-fe619fc3c96d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="cf493e31-7650-420c-adfd-0164cf6a5a7e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="4e6e1bc7-9fca-4fb7-97ce-107a3c35a178")>,
# ...

# %%
# looping the destination
Destination = []

for i in destiny:
    Destination.append(i.text)
Destination
# Out:
# ['Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
# ...

# %% [markdown]
# # departure time

# %%
#SCRAPPING departure time
Dept_Time = driver.find_elements_by_xpath("//div[@class='i-b pr']")
Dept_Time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="51ecc936-3fa2-41cd-a2e1-d4705f856f53")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="7a0393cd-d9d0-480b-a1bf-04da5f46f507")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="2ad2dda4-7384-4153-8368-4e339d423eea")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="91bf11cc-4d5a-4d36-8349-202bea81c735")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="53a17a62-b9db-4679-b64b-8cf9ad4ca219")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="0264acf7-dbfa-4ca1-bbae-3ada0f0529c7")>,
# ...

# %%
# looping the departure time
Departure_Time = []

for i in Dept_Time:
    Departure_Time.append(i.text)
Departure_Time
# Out:
# ['07:35',
#  '11:40',
#  '10:55',
#  '10:15',
#  '13:20',
#  '06:00',
#  '23:45',
#  '22:40',
#  '21:15',
#  '21:45',
#  '19:05',
#  '21:45',
#  '07:20',
#  '19:05',
#  '07:20',
#  '21:30',
#  '15:25',
#  '07:05',
#  '13:30',
#  '12:15',
#  '08:00',
#  '06:00',
#  '10:00',
#  '08:00',
#  '10:15',
#  '10:15',
#  '06:00',
#  '06:00',
#  '22:45',
#  '21:55',
#  '22:45',
#  '21:55',
#  '09:55',
#  '07:00',
#  '19:00',
#  '16:00',
#  '10:25',
#  '11:55',
#  '10:25',
#  '06:30',
#  '06:30',
#  '20:55',
#  '20:55',
#  '15:45',
#  '14:40',
#  '15:45',
#  '14:40',
#  '16:35',
#  '03:05',
#  '22:40',
#  '08:45',
#  '07:30',
#  '08:45',
#  '07:30',
#  '18:30',
#  '17:30',
#  '18:30',
#  '17:30',
#  '07:30',
#  '06:05',
#  '21:00',
#  '11:10',
#  '11:10',
#  '16:35',
#  '05:00',
#  '06:20',
#  '06:20',
#  '19:20',
#  '22:20',
#  '09:50',
#  '11:45',
#  '11:45',
#  '09:30',
#  '06:00',
#  '05:00',
#  '07:00',
#  '09:05',
#  '06:00',
#  '07:00',
#  '18:00',
#  '08:30',
#  '08:30',
#  '07:15',
# ...

# %% [markdown]
# # arrival time

# %%
#SCRAPPING arrival time
Arr_Time = driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
Arr_Time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="fa78b531-0f4f-442c-8103-fa15eb058598")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="4018de8c-632e-496a-9d09-dbac667418a5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="b8f32a7e-7e48-4d28-a85e-e4f50531fe2b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="702743ca-7489-4d09-b6cd-989cf54163a4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="c4830517-f3b8-4a37-ba49-a2285cdb31dc")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="5973d384-41d4-45ae-8262-beab0476a9b3")>,
# ...

# %%
# looping the arrival time
Arrival_Time = []

for i in Arr_Time:
    Arrival_Time.append(i.text)
Arrival_Time
# Out:
# ['09:50',
#  '14:00',
#  '13:20',
#  '12:40',
#  '15:35',
#  '10:40',
#  '10:40\n+ 1 day',
#  '10:40\n+ 1 day',
#  '10:40\n+ 1 day',
#  '18:50\n+ 1 day',
#  '18:50\n+ 1 day',
#  '08:20\n+ 1 day',
#  '18:50',
#  '08:20\n+ 1 day',
#  '08:20\n+ 1 day',
#  '11:35\n+ 1 day',
#  '11:35\n+ 1 day',
#  '11:35\n+ 1 day',
#  '20:10',
#  '20:10',
#  '20:10',
#  '20:10',
#  '11:35\n+ 1 day',
#  '11:35\n+ 1 day',
#  '18:50',
#  '08:20\n+ 1 day',
#  '14:45',
#  '17:40',
#  '14:45\n+ 1 day',
#  '14:45\n+ 1 day',
#  '17:40\n+ 1 day',
#  '17:40\n+ 1 day',
#  '20:10',
#  '11:35',
#  '11:35\n+ 1 day',
#  '11:35\n+ 1 day',
#  '14:45',
#  '17:40',
#  '17:40',
#  '14:45',
#  '17:40',
#  '14:45\n+ 1 day',
#  '17:40\n+ 1 day',
#  '14:45\n+ 1 day',
#  '14:45\n+ 1 day',
#  '17:40\n+ 1 day',
#  '17:40\n+ 1 day',
#  '11:35\n+ 1 day',
#  '11:55',
#  '12:30\n+ 1 day',
#  '14:45',
#  '14:45',
#  '17:40',
#  '17:40',
#  '14:45\n+ 1 day',
#  '14:45\n+ 1 day',
#  '17:40\n+ 1 day',
#  '17:40\n+ 1 day',
#  '12:30',
# ...

# %% [markdown]
# # duration

# %%
#SCRAPPING duration
Dur = driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
Dur
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="affea3fd-7171-4f8f-b257-b16edd00514f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="acd96ed7-06cc-4659-8b42-856d8bc694ed")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="152e0bc6-aa07-40a0-be51-0d8183e6361f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="adfdd3e5-1165-4f81-af15-1fec8de2cc70")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="da2e7c4b-a0b5-4168-a50e-bc27364c3b1e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="6efc9aa5-9e84-4c74-b651-1052953b4828")>,
# ...

# %%
# looping the duration
Duration = []

for i in Dur:
    Duration.append(i.text)
Duration
# Out:
# ['2h 15m',
#  '2h 20m',
#  '2h 25m',
#  '2h 25m',
#  '2h 15m',
#  '4h 40m',
#  '10h 55m',
#  '12h 00m',
#  '13h 25m',
#  '21h 05m',
#  '23h 45m',
#  '10h 35m',
#  '11h 30m',
#  '13h 15m',
#  '25h 00m',
#  '14h 05m',
#  '20h 10m',
#  '28h 30m',
#  '6h 40m',
#  '7h 55m',
#  '12h 10m',
#  '14h 10m',
#  '25h 35m',
#  '27h 35m',
#  '8h 35m',
#  '22h 05m',
#  '8h 45m',
#  '11h 40m',
#  '16h 00m',
#  '16h 50m',
#  '18h 55m',
#  '19h 45m',
#  '10h 15m',
#  '4h 35m',
#  '16h 35m',
#  '19h 35m',
#  '4h 20m',
#  '5h 45m',
#  '7h 15m',
#  '8h 15m',
#  '11h 10m',
#  '17h 50m',
#  '20h 45m',
#  '23h 00m',
#  '24h 05m',
#  '25h 55m',
#  '27h 00m',
#  '19h 00m',
#  '8h 50m',
#  '13h 50m',
#  '6h 00m',
#  '7h 15m',
#  '8h 55m',
#  '10h 10m',
#  '20h 15m',
#  '21h 15m',
#  '23h 10m',
#  '24h 10m',
#  '5h 00m',
#  '10h 20m',
#  '17h 45m',
#  '24h 25m',
#  '24h 25m',
#  '19h 00m',
#  '8h 40m',
#  '8h 25m',
#  '11h 20m',
#  '19h 25m',
#  '8h 10m',
#  '25h 45m',
#  '5h 05m',
#  '7h 35m',
#  '26h 05m',
# ...

# %% [markdown]
# # total stops

# %%
#SCRAPPING total stops
stops = driver.find_elements_by_xpath("//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']")
stops
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="2f56dc04-21ac-42e0-9eea-8d878911e271")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="fe5be31a-90c3-4a03-8e66-1fc429b0556b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="31f81216-74e4-4936-bb7f-13741b04ae4b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="2bdda6d2-b317-4626-b5f1-f9e4acf10314")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="cc74f840-f6cf-4802-b8c0-72e1f54d5a7c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="ea4681a4-cf1d-49ae-bf21-32f38ff18fd4")>,
# ...

# %%
# looping the total stops
Total_stops = []

for i in stops:
    Total_stops.append(i.text)
Total_stops
# Out:
# ['Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '1 Stop',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '1 Stop',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
# ...

# %% [markdown]
# # Price

# %%
#SCRAPPING Price
cost = driver.find_elements_by_xpath("//div[@class='i-b tipsy fare-summary-tooltip fs-18']")
cost
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="5c799d67-1cf1-4c31-a720-0236b46b2562")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="9caab662-5fb6-49d0-b3f0-ec768fe44101")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="c38b9191-5fb5-4a27-8df8-7087dc085da2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="be6a205b-a189-4410-af42-363efab05de2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="a108ebdd-839e-42a7-b2eb-0b913b4efe9d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ffc5146b7b9a9a658a02e800a953265", element="ebfa303b-200f-4df1-81e1-aa32a2e34ada")>,
# ...

# %%
# looping the Price
Price = []

for i in cost:
    Price.append(i.text)
Price
# Out:
# ['3,402',
#  '3,402',
#  '3,402',
#  '3,796',
#  '3,845',
#  '4,002',
#  '4,002',
#  '4,002',
#  '4,002',
#  '4,010',
#  '4,010',
#  '4,116',
#  '4,116',
#  '4,116',
#  '4,116',
#  '4,291',
#  '4,291',
#  '4,291',
#  '4,569',
#  '4,569',
#  '4,569',
#  '4,569',
#  '4,606',
#  '4,606',
#  '4,746',
#  '4,746',
#  '4,788',
#  '4,788',
#  '4,788',
#  '4,788',
#  '4,788',
#  '4,788',
#  '4,852',
#  '5,005',
#  '5,026',
#  '5,026',
#  '5,313',
#  '5,313',
#  '5,313',
#  '5,313',
#  '5,313',
#  '5,313',
#  '5,313',
#  '5,313',
#  '5,313',
#  '5,313',
#  '5,313',
#  '5,492',
#  '5,582',
#  '5,735',
#  '5,838',
#  '5,838',
#  '5,838',
#  '5,838',
#  '5,838',
#  '5,838',
#  '5,838',
#  '5,838',
#  '5,975',
#  '6,402',
#  '6,735',
#  '6,846',
#  '6,846',
#  '6,857',
#  '7,022',
#  '7,314',
#  '7,314',
#  '7,314',
#  '7,522',
#  '7,667',
#  '7,797',
#  '7,797',
#  '7,996',
#  '8,052',
#  '8,052',
#  '8,399',
#  '8,399',
#  '8,399',
#  '8,399',
#  '8,512',
#  '8,848',
#  '8,848',
#  '8,906',
# ...

# %%
# creating the dataframe for flight price prediction
df=pd.DataFrame({"Flight_name":Flight_name[0:],"Depart":Depart[0:],"Departure_Time":Departure_Time[0:],"Destination":Destination[0:],
                "Arrival_Time":Arrival_Time[0:],"Duration":Duration[0:],"Total_stops":Total_stops[0:],"Price":Price[0:]})
df
# Out:
#     Flight_name  Depart Departure_Time Destination    Arrival_Time Duration  \
# 0      SpiceJet  Mumbai          07:35    Varanasi           09:50   2h 15m
# 1        IndiGo  Mumbai          11:40    Varanasi           14:00   2h 20m
# 2      Go First  Mumbai          10:55    Varanasi           13:20   2h 25m
# 3     Air India  Mumbai          10:15    Varanasi           12:40   2h 25m
# 4       Vistara  Mumbai          13:20    Varanasi           15:35   2h 15m
# ..          ...     ...            ...         ...             ...      ...
# 105      IndiGo  Mumbai          06:00    Varanasi           16:50  10h 50m
# 106      IndiGo  Mumbai          19:35    Varanasi  06:30\n+ 1 day  10h 55m
# 107      IndiGo  Mumbai          10:30    Varanasi           19:10   8h 40m
# 108     Vistara  Mumbai          11:25    Varanasi  14:45\n+ 1 day  27h 20m
# 109     Vistara  Mumbai          11:25    Varanasi  17:40\n+ 1 day  30h 15m
#
#     Total_stops   Price
# 0      Non Stop   3,402
# ...

# %%
df.to_csv("flightprice5",index=False)

# %% [markdown]
# # Mumbai to chandigarh

# %% [markdown]
# # airline name

# %%
url="https://flight.yatra.com/air-search-ui/seodom/trigger?type=O&viewName=normal&flexi=0&noOfSegments=1&origin=BOM&originCountry=IN&destination=IXC&preferred=&destinationCountry=IN&flight_depart_date=29%2F11%2F2021&ADT=1&CHD=0&INF=0&class=Economy&source=seo"

# %%
driver.get(url)

# %%
# SCRAPPING airline name
airline_name = driver.find_elements_by_xpath("//span[@class='i-b text ellipsis']")
airline_name
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="b8d9e4be-b4aa-4de0-bf56-a086cd60b6f9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="e382aae4-4a0f-4f9e-988d-b153ab241b5a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="def5d7a0-8192-446b-aba9-8190b0873eb7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="b1b6c505-4698-4107-9c67-55d111e523b5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="3cad9635-801b-4cc6-b17d-5cffbb456940")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="9baf0bb5-be2c-4acc-9512-ece2d665ab42")>,
# ...

# %%
# looping the airline_name
Flight_name = []

for i in airline_name:
    Flight_name.append(i.text)
Flight_name
# Out:
# ['IndiGo',
#  'IndiGo',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Vistara',
#  'IndiGo',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Vistara',
#  'Air India',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Vistara',
#  'Vistara',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Go First',
#  'Air India',
#  'Air India',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'Air India',
#  'Air India',
#  'Air India',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Air India',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'IndiGo',
#  'Go First',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Go First',
# ...

# %% [markdown]
# # departure

# %%
#SCRAPPING departure
source = driver.find_elements_by_xpath("//p[@title='Mumbai']")
source
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="74cc2b6a-53bf-4a1a-9f47-0594f6d92d1e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="b864cb59-8de7-4c40-8331-0ec9b01eb314")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="a885e3b3-81d7-4749-b3e0-66c5617613cb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="e3fdd372-526f-4710-8bfe-969820994431")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="5163b964-f1b4-47ac-8255-98df7c4762da")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="e3069fec-aad5-46ea-8170-feba2bc31aec")>,
# ...

# %%
# looping the departure
Depart = []

for i in source:
    Depart.append(i.text)
Depart
# Out:
# ['Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
# ...

# %% [markdown]
# # destination

# %%
#SCRAPPING destination
destiny = driver.find_elements_by_xpath("//p[@title='Chandigarh']")
destiny
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="1ab0b724-e723-46da-a4cc-6fd789c3ee3c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="c356d1c4-a8cd-4125-b776-40e7d6573e31")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="014c77bf-1263-480f-874b-fec36eade87c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="f97920c7-9810-4d37-bfa9-e575948b65bd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="748d38c8-056d-4a31-9b8f-9a9144ed7df5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="0c0576dd-96e0-4550-8092-d1536b6110cd")>,
# ...

# %%
# looping the destination
Destination = []

for i in destiny:
    Destination.append(i.text)
Destination
# Out:
# ['Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
# ...

# %% [markdown]
# # departure time

# %%
#SCRAPPING departure time
Dept_Time = driver.find_elements_by_xpath("//div[@class='i-b pr']")
Dept_Time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="4498909a-6197-45be-a88e-09db12ed0d9a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="ac85a08d-976f-47b3-8389-88220ec4ff65")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="e347bc57-ce31-40e3-9aa3-3ff07e563517")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="a56fac1a-d4ef-4ec2-a041-a8e2b639f3c2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="2a97392c-ea15-405e-9b39-465c000d5e26")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="307e3606-8a90-41c0-a650-339df5353918")>,
# ...

# %%
# looping the departure time
Departure_Time = []

for i in Dept_Time:
    Departure_Time.append(i.text)
Departure_Time
# Out:
# ['15:35',
#  '20:00',
#  '17:05',
#  '09:00',
#  '05:00',
#  '06:00',
#  '03:05',
#  '06:00',
#  '23:45',
#  '22:40',
#  '21:15',
#  '16:05',
#  '21:30',
#  '06:00',
#  '22:45',
#  '21:55',
#  '05:00',
#  '07:45',
#  '21:30',
#  '15:25',
#  '07:05',
#  '22:45',
#  '21:55',
#  '07:00',
#  '07:45',
#  '05:00',
#  '13:40',
#  '03:05',
#  '11:45',
#  '10:05',
#  '09:20',
#  '07:00',
#  '11:55',
#  '10:25',
#  '06:30',
#  '20:55',
#  '06:00',
#  '22:40',
#  '19:00',
#  '18:00',
#  '08:00',
#  '10:05',
#  '09:20',
#  '07:05',
#  '06:00',
#  '20:55',
#  '19:00',
#  '18:00',
#  '08:00',
#  '09:40',
#  '08:45',
#  '10:25',
#  '06:30',
#  '10:00',
#  '08:30',
#  '08:45',
#  '07:05',
#  '21:00',
#  '21:00',
#  '17:50',
#  '17:50',
#  '17:50',
#  '08:30',
#  '09:25',
#  '21:00',
#  '17:50',
#  '17:50',
#  '09:45',
#  '09:45',
#  '07:30',
#  '21:00',
#  '09:05',
#  '17:30',
#  '16:00',
#  '11:10',
#  '06:20',
#  '11:10',
#  '06:35',
#  '19:10',
#  '06:20',
#  '05:50',
#  '15:50',
#  '13:40',
# ...

# %% [markdown]
# # arrival time

# %%
#SCRAPPING arrival time
Arr_Time = driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
Arr_Time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="6db367a2-6cf0-4c56-8757-9639f2dbf0a8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="cd45a4fe-e660-41c6-b7a3-917b0ca34aaa")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="52b67aab-0fc1-4ac8-bc68-30734bf4693c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="43b2c300-bcd0-492b-95dd-e31ba7367461")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="c35761b9-5983-4a40-8205-c80cc7d131f0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="d476dd4a-d69e-46dd-ad38-3f1086c64da3")>,
# ...

# %%
# looping the arrival time
Arrival_Time = []

for i in Arr_Time:
    Arrival_Time.append(i.text)
Arrival_Time
# Out:
# ['17:50',
#  '22:15',
#  '19:25',
#  '11:25',
#  '07:30',
#  '08:20',
#  '11:15',
#  '11:30',
#  '11:30\n+ 1 day',
#  '11:30\n+ 1 day',
#  '11:30\n+ 1 day',
#  '18:30',
#  '07:40\n+ 1 day',
#  '18:15',
#  '18:15\n+ 1 day',
#  '18:15\n+ 1 day',
#  '09:25',
#  '18:40',
#  '06:35\n+ 1 day',
#  '06:35\n+ 1 day',
#  '06:35\n+ 1 day',
#  '14:45\n+ 1 day',
#  '14:45\n+ 1 day',
#  '07:40\n+ 1 day',
#  '15:45',
#  '15:45',
#  '18:40',
#  '09:25',
#  '18:40',
#  '18:40',
#  '18:40',
#  '06:35\n+ 1 day',
#  '18:15',
#  '18:15',
#  '18:15',
#  '18:15\n+ 1 day',
#  '14:45',
#  '11:20\n+ 1 day',
#  '07:40\n+ 1 day',
#  '07:40\n+ 1 day',
#  '07:40\n+ 1 day',
#  '15:45',
#  '15:45',
#  '15:45',
#  '15:45',
#  '14:45\n+ 1 day',
#  '06:35\n+ 1 day',
#  '06:35\n+ 1 day',
#  '06:35\n+ 1 day',
#  '11:55',
#  '18:15',
#  '14:45',
#  '14:45',
#  '06:35\n+ 1 day',
#  '18:40',
#  '14:45',
#  '18:15',
#  '18:15\n+ 1 day',
#  '18:15\n+ 1 day',
#  '18:15\n+ 1 day',
#  '18:15\n+ 1 day',
#  '18:15\n+ 1 day',
# ...

# %% [markdown]
# # duration

# %%
#SCRAPPING duration
Dur = driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
Dur
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="f2bce0ba-83f1-4683-aacd-4d6e405e00cc")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="17e9e856-c50b-4644-9c57-e7659bf1fa8a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="7736b50a-2c05-4651-8e91-badd2a86ed36")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="3bc39684-ea2c-4175-a3b6-64786541d0c3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="1177a4da-641b-4a8c-9681-23e627cde72e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="b6f92a79-43e2-4440-912f-87828b7e4bba")>,
# ...

# %%
# looping the duration
Duration = []

for i in Dur:
    Duration.append(i.text)
Duration
# Out:
# ['2h 15m',
#  '2h 15m',
#  '2h 20m',
#  '2h 25m',
#  '2h 30m',
#  '2h 20m',
#  '8h 10m',
#  '5h 30m',
#  '11h 45m',
#  '12h 50m',
#  '14h 15m',
#  '2h 25m',
#  '10h 10m',
#  '12h 15m',
#  '19h 30m',
#  '20h 20m',
#  '4h 25m',
#  '10h 55m',
#  '9h 05m',
#  '15h 10m',
#  '23h 30m',
#  '16h 00m',
#  '16h 50m',
#  '24h 40m',
#  '8h 00m',
#  '10h 45m',
#  '5h 00m',
#  '6h 20m',
#  '6h 55m',
#  '8h 35m',
#  '9h 20m',
#  '23h 35m',
#  '6h 20m',
#  '7h 50m',
#  '11h 45m',
#  '21h 20m',
#  '8h 45m',
#  '12h 40m',
#  '12h 40m',
#  '13h 40m',
#  '23h 40m',
#  '5h 40m',
#  '6h 25m',
#  '8h 40m',
#  '9h 45m',
#  '17h 50m',
#  '11h 35m',
#  '12h 35m',
#  '22h 35m',
#  '2h 15m',
#  '9h 30m',
#  '4h 20m',
#  '8h 15m',
#  '20h 35m',
#  '10h 10m',
#  '6h 00m',
#  '11h 10m',
#  '21h 15m',
#  '21h 15m',
#  '24h 25m',
#  '24h 25m',
#  '24h 25m',
#  '7h 15m',
#  '6h 55m',
#  '17h 45m',
#  '20h 55m',
#  '20h 55m',
#  '29h 00m',
#  '29h 00m',
#  '8h 50m',
#  '16h 20m',
#  '28h 15m',
#  '19h 50m',
# ...

# %% [markdown]
# # total stops

# %%
#SCRAPPING total stops
stops = driver.find_elements_by_xpath("//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']")
stops
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="9a10f218-a933-483a-81f0-839e8b67dff4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="2e82f951-ebfb-4589-ac21-46cbfa5814c8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="ca8deca4-e57c-4adb-b9ec-c3430240fb6f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="cc7dba95-77ae-440b-8d23-b68b00490f04")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="991ec912-4557-4ef9-a6fd-d2e5e4bb9526")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="99377956-16cd-49fe-9476-c194ddf92b30")>,
# ...

# %%
# looping the total stops
Total_stops = []

for i in stops:
    Total_stops.append(i.text)
Total_stops
# Out:
# ['Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
# ...

# %% [markdown]
# # Price

# %%
#SCRAPPING Price
cost = driver.find_elements_by_xpath("//div[@class='i-b tipsy fare-summary-tooltip fs-18']")
cost
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="f92bbe1b-dd1d-440e-aa7b-2291198d04c2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="a9548177-87b9-48b5-8a2c-a1bbfd3873aa")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="2a9a2561-481f-4f34-baea-c1353f846cff")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="3601d26d-dc89-454e-a988-51e5bc35ea87")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="4b4a0478-5985-44a6-86bf-bf43a51f5c75")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="bf918e51-5ce9-40c4-ab8a-afada7db90d1")>,
# ...

# %%
# looping the Price
Price = []

for i in cost:
    Price.append(i.text)
Price
# Out:
# ['3,301',
#  '3,301',
#  '3,301',
#  '3,301',
#  '3,301',
#  '3,398',
#  '3,631',
#  '3,646',
#  '3,646',
#  '3,646',
#  '3,646',
#  '3,698',
#  '3,777',
#  '3,800',
#  '3,800',
#  '3,800',
#  '3,881',
#  '3,881',
#  '3,976',
#  '3,976',
#  '3,976',
#  '4,010',
#  '4,010',
#  '4,092',
#  '4,196',
#  '4,196',
#  '4,208',
#  '4,208',
#  '4,208',
#  '4,208',
#  '4,208',
#  '4,291',
#  '4,325',
#  '4,325',
#  '4,325',
#  '4,325',
#  '4,405',
#  '4,500',
#  '4,512',
#  '4,512',
#  '4,512',
#  '4,523',
#  '4,523',
#  '4,523',
#  '4,523',
#  '4,535',
#  '4,711',
#  '4,711',
#  '4,711',
#  '4,755',
#  '4,825',
#  '4,930',
#  '4,930',
#  '5,236',
#  '5,259',
#  '5,430',
#  '5,480',
#  '5,480',
#  '5,480',
#  '5,480',
#  '5,480',
#  '5,480',
#  '5,574',
#  '5,679',
#  '5,690',
#  '5,690',
#  '5,690',
#  '5,690',
#  '5,690',
#  '5,919',
#  '5,966',
#  '5,966',
#  '6,281',
#  '6,281',
#  '6,311',
#  '6,324',
#  '6,332',
#  '6,523',
#  '6,911',
#  '6,929',
#  '6,960',
#  '7,151',
#  '7,411',
# ...

# %%
# creating the dataframe for flight price prediction
df=pd.DataFrame({"Flight_name":Flight_name[0:],"Depart":Depart[0:],"Departure_Time":Departure_Time[0:],"Destination":Destination[0:],
                "Arrival_Time":Arrival_Time[0:],"Duration":Duration[0:],"Total_stops":Total_stops[0:],"Price":Price[0:]})
df
# Out:
#    Flight_name  Depart Departure_Time Destination    Arrival_Time Duration  \
# 0       IndiGo  Mumbai          15:35  Chandigarh           17:50   2h 15m
# 1       IndiGo  Mumbai          20:00  Chandigarh           22:15   2h 15m
# 2     Go First  Mumbai          17:05  Chandigarh           19:25   2h 20m
# 3     Go First  Mumbai          09:00  Chandigarh           11:25   2h 25m
# 4     Go First  Mumbai          05:00  Chandigarh           07:30   2h 30m
# ..         ...     ...            ...         ...             ...      ...
# 95     Vistara  Mumbai          06:00  Chandigarh           13:20   7h 20m
# 96     Vistara  Mumbai          17:15  Chandigarh  14:45\n+ 1 day  21h 30m
# 97     Vistara  Mumbai          14:00  Chandigarh  14:45\n+ 1 day  24h 45m
# 98      IndiGo  Mumbai          14:05  Chandigarh           20:30   6h 25m
# 99      IndiGo  Mumbai          11:30  Chandigarh           20:30   9h 00m
#
#    Total_stops   Price
# 0     Non Stop   3,301
# ...

# %%
df.to_csv("flightprice6",index=False)

# %% [markdown]
# # Mumbai to Dehradun

# %%
url="https://flight.yatra.com/air-search-ui/seodom/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=DED&destinationCountry=IN&flexi=0&flight_depart_date=08%2F01%2F2022&hb=0&noOfSegments=1&origin=BOM&originCountry=IN&type=O&unique=372138507398&version=1.1&viewName=normal"

# %%
driver.get(url)

# %% [markdown]
# # airline name

# %%
# SCRAPPING airline name
airline_name = driver.find_elements_by_xpath("//span[@class='i-b text ellipsis']")
airline_name
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="7fb2a19e-a4da-4119-aaa8-78beadfbd166")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="6a460ec8-566c-489b-8ef6-3fe54da2a420")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="e0f37967-b51b-49e2-8847-3dfddbd51045")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="62615f14-d090-48b9-af06-a1c09dbc70f8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="bff35699-a663-492c-94cb-8a35ed40d07d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="3902f7a1-92bf-4a66-aaa2-de02b9639477")>,
# ...

# %%
# looping the airline_name
Flight_name = []

for i in airline_name:
    Flight_name.append(i.text)
Flight_name
# Out:
# ['Air India',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'IndiGo',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
# ...

# %% [markdown]
# # departure

# %%
#SCRAPPING departure
source = driver.find_elements_by_xpath("//p[@title='Mumbai']")
source
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="d4dadbaa-3d31-4398-b29c-79c79882a5c0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="d16f96e7-ad78-4815-8350-8377f31a4f2e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="3ee4f948-e7d8-4197-ab75-1443a123343e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="22b414f3-4d15-4d55-9d52-4f79ce2e81e1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="13f1abd6-ed8a-460e-86a0-7f6e109a723d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="b02ffb10-a92f-468d-846d-027a9636d6f4")>,
# ...

# %%
# looping the departure
Depart = []

for i in source:
    Depart.append(i.text)
Depart
# Out:
# ['Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
# ...

# %% [markdown]
# # destination

# %%
#SCRAPPING destination
destiny = driver.find_elements_by_xpath("//p[@title='Dehradun']")
destiny
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="f7816ce5-0bc1-46df-a169-27d2561a524c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="c660b9ee-8fb3-4cbe-807c-7e710bf2263c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="b81a066b-3b18-48d8-8717-c7367f74b4f3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="c43a12db-b3f4-43bc-97aa-aa392f4ea048")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="a47d48c9-0454-4348-8926-73003ab8bd20")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="28555d91-1c5e-4489-b121-b80d6754591f")>,
# ...

# %%
# looping the destination
Destination = []

for i in destiny:
    Destination.append(i.text)
Destination
# Out:
# ['Dehradun',
#  'Dehradun',
#  'Dehradun',
#  'Dehradun',
#  'Dehradun',
#  'Dehradun',
#  'Dehradun',
#  'Dehradun',
#  'Dehradun',
#  'Dehradun',
#  'Dehradun',
#  'Dehradun',
#  'Dehradun',
#  'Dehradun',
#  'Dehradun',
#  'Dehradun',
#  'Dehradun',
#  'Dehradun',
#  'Dehradun',
#  'Dehradun',
#  'Dehradun',
#  'Dehradun',
#  'Dehradun',
#  'Dehradun',
#  'Dehradun',
#  'Dehradun',
#  'Dehradun',
#  'Dehradun',
#  'Dehradun',
#  'Dehradun',
#  'Dehradun',
#  'Dehradun',
#  'Dehradun',
#  'Dehradun',
#  'Dehradun',
#  'Dehradun',
#  'Dehradun',
#  'Dehradun',
#  'Dehradun',
#  'Dehradun',
#  'Dehradun',
#  'Dehradun',
#  'Dehradun',
#  'Dehradun',
#  'Dehradun',
#  'Dehradun',
#  'Dehradun',
#  'Dehradun',
#  'Dehradun',
#  'Dehradun',
#  'Dehradun',
#  'Dehradun',
#  'Dehradun',
#  'Dehradun',
#  'Dehradun',
#  'Dehradun',
#  'Dehradun',
#  'Dehradun',
#  'Dehradun',
#  'Dehradun',
#  'Dehradun',
#  'Dehradun',
#  'Dehradun',
#  'Dehradun',
#  'Dehradun',
#  'Dehradun',
# ...

# %% [markdown]
# # departure time

# %%
#SCRAPPING departure time
Dept_Time = driver.find_elements_by_xpath("//div[@class='i-b pr']")
Dept_Time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="2300cae8-1cea-4e0a-8b08-9da20467bc96")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="9ebb8f57-0730-481f-ad0d-7bce18c25a87")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="a34f78bd-8708-4f1c-a386-743e2714dc5e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="594709b9-90cb-43ce-b64a-5c34009ae183")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="18404f3b-bc6f-45c3-a249-212d67731900")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="b373e6d9-27b2-4f8a-80a8-ee8abce2b821")>,
# ...

# %%
# looping the departure time
Departure_Time = []

for i in Dept_Time:
    Departure_Time.append(i.text)
Departure_Time
# Out:
# ['08:15',
#  '10:15',
#  '07:20',
#  '10:15',
#  '21:45',
#  '07:20',
#  '19:05',
#  '21:45',
#  '19:05',
#  '21:45',
#  '10:15',
#  '19:05',
#  '07:20',
#  '08:00',
#  '07:05',
#  '08:00',
#  '07:05',
#  '15:25',
#  '15:25',
#  '08:00',
#  '07:05',
#  '15:25',
#  '07:00',
#  '21:30',
#  '07:00',
#  '18:00',
#  '21:30',
#  '18:00',
#  '21:30',
#  '07:00',
#  '18:00',
#  '14:50',
#  '10:00',
#  '16:00',
#  '16:00',
#  '06:00',
#  '22:45',
#  '21:55',
#  '10:25',
#  '06:30',
#  '20:55',
#  '15:45',
#  '14:40',
#  '11:55',
#  '08:45',
#  '07:30',
#  '19:45',
#  '18:30',
#  '17:30',
#  '19:00',
#  '19:00',
#  '19:00',
#  '05:35',
#  '05:35',
#  '05:45',
#  '05:00',
#  '22:20',
#  '22:20',
#  '03:05',
#  '11:45',
#  '08:30',
#  '03:05',
#  '08:30',
#  '08:30',
#  '08:00',
#  '07:00',
#  '06:00',
#  '21:00',
#  '05:50',
#  '09:30',
#  '07:45',
#  '06:55',
#  '04:50',
#  '06:00',
#  '10:05',
#  '05:00',
#  '09:20',
#  '07:45',
#  '10:05',
#  '07:05',
#  '09:20',
#  '06:00',
#  '07:45',
# ...

# %% [markdown]
# # arrival time

# %%
#SCRAPPING arrival time
Arr_Time = driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
Arr_Time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="70d0c7ca-767a-46b1-9917-75442cb5d5da")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="bc50d3fc-ced7-4331-8222-e2538bc810c3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="5e4adcae-8fa4-436a-95a3-a27a64852e42")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="82100171-627e-4894-99f9-3c3b6677b4a5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="ba69cea0-731c-4882-8562-987bd01bdb23")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="93a5b807-8095-4658-82ce-1c8fed997718")>,
# ...

# %%
# looping the arrival time
Arrival_Time = []

for i in Arr_Time:
    Arrival_Time.append(i.text)
Arrival_Time
# Out:
# ['10:15',
#  '16:00',
#  '16:00',
#  '19:00',
#  '08:00\n+ 1 day',
#  '19:00',
#  '08:00\n+ 1 day',
#  '16:00\n+ 1 day',
#  '16:00\n+ 1 day',
#  '19:00\n+ 1 day',
#  '08:00\n+ 1 day',
#  '19:00\n+ 1 day',
#  '08:00\n+ 1 day',
#  '13:45',
#  '13:45',
#  '19:15',
#  '19:15',
#  '07:25\n+ 1 day',
#  '13:45\n+ 1 day',
#  '07:25\n+ 1 day',
#  '07:25\n+ 1 day',
#  '19:15\n+ 1 day',
#  '13:45',
#  '07:25\n+ 1 day',
#  '19:15',
#  '07:25\n+ 1 day',
#  '13:45\n+ 1 day',
#  '13:45\n+ 1 day',
#  '19:15\n+ 1 day',
#  '07:25\n+ 1 day',
#  '19:15\n+ 1 day',
#  '17:05',
#  '19:15',
#  '07:25\n+ 1 day',
#  '13:45\n+ 1 day',
#  '14:45',
#  '14:45\n+ 1 day',
#  '14:45\n+ 1 day',
#  '14:45',
#  '14:45',
#  '14:45\n+ 1 day',
#  '14:45\n+ 1 day',
#  '14:45\n+ 1 day',
#  '14:45\n+ 1 day',
#  '14:45',
#  '14:45',
#  '14:45\n+ 1 day',
#  '14:45\n+ 1 day',
#  '14:45\n+ 1 day',
#  '07:25\n+ 1 day',
#  '13:45\n+ 1 day',
#  '19:15\n+ 1 day',
#  '13:45',
#  '19:15',
#  '19:15',
#  '19:15',
#  '07:10\n+ 1 day',
# ...

# %% [markdown]
# # duration

# %%
#SCRAPPING duration
Dur = driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
Dur
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="ed2d0780-fdd7-40cf-b998-b71185e83223")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="5f384961-9c1f-4cec-a275-2bb2948f3919")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="984268fa-0180-43a5-87d4-2414a4efd422")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="f7fdd6e0-df1c-4551-8ae1-02182da065ee")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="6d6c7b32-62e9-4fab-949a-bd3a6c9b0721")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="b67b7dab-e34b-4667-add7-f1f8d5ff5a94")>,
# ...

# %%
# looping the duration
Duration = []

for i in Dur:
    Duration.append(i.text)
Duration
# Out:
# ['2h 00m',
#  '5h 45m',
#  '8h 40m',
#  '8h 45m',
#  '10h 15m',
#  '11h 40m',
#  '12h 55m',
#  '18h 15m',
#  '20h 55m',
#  '21h 15m',
#  '21h 45m',
#  '23h 55m',
#  '24h 40m',
#  '5h 45m',
#  '6h 40m',
#  '11h 15m',
#  '12h 10m',
#  '16h 00m',
#  '22h 20m',
#  '23h 25m',
#  '24h 20m',
#  '27h 50m',
#  '6h 45m',
#  '9h 55m',
#  '12h 15m',
#  '13h 25m',
#  '16h 15m',
#  '19h 45m',
#  '21h 45m',
#  '24h 25m',
#  '25h 15m',
#  '2h 15m',
#  '9h 15m',
#  '15h 25m',
#  '21h 45m',
#  '8h 45m',
#  '16h 00m',
#  '16h 50m',
#  '4h 20m',
#  '8h 15m',
#  '17h 50m',
#  '23h 00m',
#  '24h 05m',
#  '26h 50m',
#  '6h 00m',
#  '7h 15m',
#  '19h 00m',
#  '20h 15m',
#  '21h 15m',
#  '12h 25m',
#  '18h 45m',
#  '24h 15m',
#  '8h 10m',
#  '13h 40m',
#  '13h 30m',
#  '14h 15m',
#  '8h 50m',
#  '10h 00m',
#  '5h 15m',
#  '6h 15m',
#  '6h 55m',
#  '7h 30m',
#  '9h 30m',
#  '7h 10m',
#  '2h 00m',
#  '7h 45m',
#  '8h 45m',
#  '17h 45m',
#  '9h 20m',
#  '6h 10m',
#  '7h 55m',
#  '8h 45m',
#  '10h 50m',
# ...

# %% [markdown]
# # total stops

# %%
#SCRAPPING total stops
stops = driver.find_elements_by_xpath("//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']")
stops
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="a4a98c2a-de7e-4b9e-948f-dbdc2ee5e12e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="e1fe847d-d3e8-4751-8222-6bd7f025fad8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="8877244f-bbc3-46ed-a3f6-b63aa640a519")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="5a4c7a99-8adb-4331-9dd3-e7b78708133c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="a7e5d5be-b2d5-4a6c-95f2-b5f7db3eff5d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="a34193a9-5b9c-4464-ac89-ab1049b4196a")>,
# ...

# %%
# looping the total stops
Total_stops = []

for i in stops:
    Total_stops.append(i.text)
Total_stops
# Out:
# ['Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '1 Stop',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '1 Stop',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
# ...

# %% [markdown]
# # Price

# %%
#SCRAPPING Price
cost = driver.find_elements_by_xpath("//div[@class='i-b tipsy fare-summary-tooltip fs-18']")
cost
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="ca2519c8-32f3-4d64-9cdd-6515c92da838")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="7c2ee9a8-8b9e-49a9-9277-8d39a686e61e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="729cc6a7-1e77-4e11-baf9-6ebcea7b6bcb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="487f27c0-be5d-4f4e-9340-87b658e194a6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="37ffb667-d312-4bc5-8692-b9f52de87f55")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="57b19501-a621-47ab-94bd-d1d64ac78021")>,
# ...

# %%
# looping the Price
Price = []

for i in cost:
    Price.append(i.text)
Price
# Out:
# ['4,394',
#  '4,487',
#  '4,487',
#  '4,487',
#  '4,487',
#  '4,487',
#  '4,487',
#  '4,487',
#  '4,487',
#  '4,487',
#  '4,487',
#  '4,487',
#  '4,487',
#  '4,617',
#  '4,617',
#  '4,617',
#  '4,617',
#  '4,617',
#  '4,617',
#  '4,617',
#  '4,617',
#  '4,617',
#  '4,932',
#  '4,932',
#  '4,932',
#  '4,932',
#  '4,932',
#  '4,932',
#  '4,932',
#  '4,932',
#  '4,932',
#  '5,177',
#  '5,352',
#  '5,352',
#  '5,352',
#  '5,593',
#  '5,593',
#  '5,593',
#  '5,870',
#  '5,870',
#  '5,870',
#  '5,870',
#  '5,870',
#  '5,870',
#  '6,185',
#  '6,185',
#  '6,185',
#  '6,185',
#  '6,185',
#  '6,297',
#  '6,297',
#  '6,297',
#  '6,374',
#  '6,374',
#  '6,888',
#  '8,112',
#  '8,658',
#  '8,658',
#  '8,933',
#  '8,933',
#  '8,933',
#  '8,933',
#  '8,933',
#  '9,317',
#  '9,566',
#  '9,942',
#  '9,942',
#  '9,942',
#  '10,301',
#  '11,636',
#  '11,636',
#  '11,636',
#  '11,636',
#  '12,090',
#  '12,090',
#  '12,090',
#  '12,090',
#  '12,090',
#  '12,090',
#  '12,090',
#  '12,090',
#  '12,090',
# ...

# %%
# creating the dataframe for flight price prediction
df=pd.DataFrame({"Flight_name":Flight_name[0:],"Depart":Depart[0:],"Departure_Time":Departure_Time[0:],"Destination":Destination[0:],
                "Arrival_Time":Arrival_Time[0:],"Duration":Duration[0:],"Total_stops":Total_stops[0:],"Price":Price[0:]})
df
# Out:
#    Flight_name  Depart Departure_Time Destination    Arrival_Time Duration  \
# 0    Air India  Mumbai          08:15    Dehradun           10:15   2h 00m
# 1     SpiceJet  Mumbai          10:15    Dehradun           16:00   5h 45m
# 2     SpiceJet  Mumbai          07:20    Dehradun           16:00   8h 40m
# 3     SpiceJet  Mumbai          10:15    Dehradun           19:00   8h 45m
# 4     SpiceJet  Mumbai          21:45    Dehradun  08:00\n+ 1 day  10h 15m
# ..         ...     ...            ...         ...             ...      ...
# 82      IndiGo  Mumbai          07:45    Dehradun           18:00  10h 15m
# 83      IndiGo  Mumbai          05:00    Dehradun           15:25  10h 25m
# 84      IndiGo  Mumbai          20:30    Dehradun  07:10\n+ 1 day  10h 40m
# 85      IndiGo  Mumbai          07:05    Dehradun           18:00  10h 55m
# 86     Vistara  Mumbai          06:20    Dehradun           14:45   8h 25m
#
#    Total_stops   Price
# 0     Non Stop   4,394
# ...

# %%
df.to_csv("flightprice7",index=False)

# %% [markdown]
# # Mumbai to Goa

# %%
url="https://flight.yatra.com/air-search-ui/seodom/trigger?type=O&viewName=normal&flexi=0&noOfSegments=1&origin=BOM&originCountry=IN&destination=GOI&preferred=&destinationCountry=IN&flight_depart_date=27%2F11%2F2021&ADT=1&CHD=0&INF=0&class=Economy&source=seo"

# %%
driver.get(url)

# %% [markdown]
# # airline name

# %%
# SCRAPPING airline name
airline_name = driver.find_elements_by_xpath("//span[@class='i-b text ellipsis']")
airline_name
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="78212dcb-931c-40bd-a200-822011d3ad02")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="13097b74-d6ec-4b48-aab9-b8e7c11b055b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="ad982e8a-7f68-447c-9362-bc42aeb76e6a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="5ca0c597-841d-40c2-9e82-96d529d83635")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="93359c7e-b479-48bd-9677-79f0b0761464")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="d46a44ad-bcb9-45bb-9218-86b8351dad1c")>,
# ...

# %%
# looping the airline_name
Flight_name = []

for i in airline_name:
    Flight_name.append(i.text)
Flight_name
# Out:
# ['Air India',
#  'Air Asia',
#  'IndiGo',
#  'SpiceJet',
#  'Go First',
#  'Air Asia',
#  'Go First',
#  'Go First',
#  'Air India',
#  'SpiceJet',
#  'Go First',
#  'Go First',
#  'IndiGo',
#  'IndiGo',
#  'Air Asia',
#  'Air Asia',
#  'Air India',
#  'SpiceJet',
#  'IndiGo',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Vistara',
#  'Air India',
#  'Air Asia',
#  'Air Asia',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'Air India',
#  'Go First',
#  'Vistara',
#  'Air Asia',
#  'Go First',
#  'Air Asia',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Air India',
#  'Air India',
#  'Vistara',
#  'Go First',
#  'Go First',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Air India',
#  'Air Asia',
#  'Go First',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Air India',
#  'Go First',
#  'Go First',
#  'Air India',
#  'Air India',
#  'Air India',
# ...

# %% [markdown]
# # departure

# %%
#SCRAPPING departure
source = driver.find_elements_by_xpath("//p[@title='Mumbai']")
source
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="e762b2e2-0e17-486f-aea7-05541332fc8f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="5f5bc589-d420-489a-aabe-5ad119cc308d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="9438ab48-fbd1-42a4-8b8d-6575c35a3555")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="18935499-30be-479c-a47d-37260ea7eb81")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="4580eb23-d6cc-459a-98fd-24b5945df0ac")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="cc169302-fa08-4869-806d-00bf79622b7f")>,
# ...

# %%
# looping the departure
Depart = []

for i in source:
    Depart.append(i.text)
Depart
# Out:
# ['Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
# ...

# %% [markdown]
# # destination

# %%
#SCRAPPING destination
destiny = driver.find_elements_by_xpath("//p[@title='Goa']")
destiny
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="8149d5a7-45e7-4291-a654-158fdec7cf16")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="ba9b7835-e6ee-4540-9224-1f78c01a5a57")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="49af009f-8161-4d1b-a3fa-75df52b1bf9b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="97f8bc9d-9b79-4e4d-a7fb-dadf0977ba6f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="c8e374bb-a166-4d2f-9bcf-94494abe5d07")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="29efcc95-49ac-49cd-be05-72a40fb57172")>,
# ...

# %%
# looping the destination
Destination = []

for i in destiny:
    Destination.append(i.text)
Destination
# Out:
# ['Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
# ...

# %% [markdown]
# # departure time

# %%
#SCRAPPING departure time
Dept_Time = driver.find_elements_by_xpath("//div[@class='i-b pr']")
Dept_Time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="3575c1f1-9226-4e03-b063-c8cd7c3dfd3e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="d5974176-d04a-4192-b576-cd99c170f359")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="128441a8-52e2-4e77-a4d9-a228f9de4073")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="ec0ce8ed-4069-48e5-8596-8cd4204d1beb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="ab2a9796-0c0f-446f-b10c-60ab074bffc9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="10920e97-c638-41fe-96cd-5f8eec0702a2")>,
# ...

# %%
# looping the departure time
Departure_Time = []

for i in Dept_Time:
    Departure_Time.append(i.text)
Departure_Time
# Out:
# ['21:00',
#  '23:35',
#  '00:25',
#  '23:45',
#  '22:05',
#  '04:45',
#  '04:55',
#  '16:20',
#  '19:05',
#  '15:30',
#  '15:20',
#  '11:30',
#  '16:55',
#  '05:15',
#  '13:05',
#  '21:20',
#  '05:30',
#  '11:15',
#  '14:05',
#  '12:00',
#  '09:25',
#  '06:05',
#  '07:30',
#  '21:00',
#  '05:45',
#  '13:05',
#  '02:35',
#  '11:30',
#  '19:10',
#  '17:30',
#  '21:30',
#  '07:30',
#  '16:00',
#  '22:55',
#  '13:30',
#  '22:55',
#  '19:20',
#  '10:45',
#  '06:20',
#  '15:25',
#  '07:05',
#  '11:25',
#  '12:15',
#  '08:00',
#  '09:05',
#  '07:00',
#  '06:00',
#  '18:00',
#  '07:20',
#  '09:55',
#  '21:30',
#  '16:00',
#  '08:00',
#  '07:00',
#  '05:20',
#  '13:25',
#  '10:00',
#  '23:45',
#  '22:40',
#  '21:15',
#  '19:00',
#  '23:45',
#  '22:40',
#  '21:30',
#  '21:30',
#  '15:25',
#  '15:25',
#  '15:25',
#  '07:05',
#  '21:30',
#  '19:00',
#  '18:00',
#  '15:25',
#  '19:00',
#  '18:00',
#  '19:00',
#  '18:00',
#  '16:00',
#  '16:00',
#  '08:00',
#  '06:00',
#  '16:00',
#  '14:40',
# ...

# %% [markdown]
# # arrival time

# %%
#SCRAPPING arrival time
Arr_Time = driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
Arr_Time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="7218b2e0-161e-4ea5-9b4a-0dc306320d4c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="146e18d3-c0a9-42d7-a948-79b94a7b72b3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="425407c9-e1d8-46ac-b40a-1d563709dc9b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="689dac00-2e95-44ad-a1e8-94d17367b0cf")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="1640f808-fbe0-4900-b4a2-07af9cb7e137")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="c1a3e4de-1b4d-4709-a5f7-51b7c36908c4")>,
# ...

# %%
# looping the arrival time
Arrival_Time = []

for i in Arr_Time:
    Arrival_Time.append(i.text)
Arrival_Time
# Out:
# ['22:35',
#  '00:35\n+ 1 day',
#  '01:35',
#  '01:00\n+ 1 day',
#  '23:25',
#  '05:55',
#  '06:10',
#  '17:45',
#  '20:30',
#  '17:05',
#  '16:30',
#  '12:45',
#  '18:00',
#  '06:25',
#  '22:00',
#  '07:00\n+ 1 day',
#  '06:50',
#  '12:50',
#  '15:15',
#  '20:10',
#  '20:10',
#  '17:10',
#  '20:10',
#  '13:50\n+ 1 day',
#  '17:00',
#  '19:35',
#  '19:35',
#  '12:35',
#  '13:50\n+ 1 day',
#  '13:50\n+ 1 day',
#  '00:35\n+ 2 days',
#  '12:40',
#  '13:50\n+ 1 day',
#  '14:55\n+ 1 day',
#  '23:10',
#  '07:50\n+ 1 day',
#  '13:50\n+ 1 day',
#  '13:50\n+ 1 day',
#  '13:50\n+ 1 day',
#  '00:35\n+ 1 day',
#  '00:35\n+ 1 day',
#  '12:45',
#  '23:10',
#  '23:10',
#  '13:50',
#  '13:50',
#  '13:50',
#  '00:35\n+ 1 day',
#  '22:35',
#  '23:10',
#  '10:05\n+ 1 day',
#  '00:35\n+ 1 day',
#  '00:35\n+ 1 day',
#  '00:35\n+ 1 day',
#  '17:00',
#  '14:45',
#  '00:35\n+ 1 day',
#  '11:30\n+ 1 day',
#  '11:30\n+ 1 day',
#  '11:30\n+ 1 day',
#  '10:05\n+ 1 day',
#  '13:30\n+ 1 day',
#  '13:30\n+ 1 day',
# ...

# %% [markdown]
# # duration

# %%
#SCRAPPING duration
Dur = driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
Dur
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="ed16a0d9-ed33-4b63-855e-aa2ba7348867")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="eb69be27-b591-4f91-ac14-37cab6a955f4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="84f325b3-8ee6-4fd8-baa5-da690e351d5b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="a866527e-ee0d-4360-9e5d-7be46918d804")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="ae045986-2221-4220-97e6-71b4dbaead23")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="c056ca56-5bc8-487f-b45b-dafe14342b3a")>,
# ...

# %%
# looping the duration
Duration = []

for i in Dur:
    Duration.append(i.text)
Duration
# Out:
# ['1h 35m',
#  '1h 00m',
#  '1h 10m',
#  '1h 15m',
#  '1h 20m',
#  '1h 10m',
#  '1h 15m',
#  '1h 25m',
#  '1h 25m',
#  '1h 35m',
#  '1h 10m',
#  '1h 15m',
#  '1h 05m',
#  '1h 10m',
#  '8h 55m',
#  '9h 40m',
#  '1h 20m',
#  '1h 35m',
#  '1h 10m',
#  '8h 10m',
#  '10h 45m',
#  '11h 05m',
#  '12h 40m',
#  '16h 50m',
#  '11h 15m',
#  '6h 30m',
#  '17h 00m',
#  '1h 05m',
#  '18h 40m',
#  '20h 20m',
#  '27h 05m',
#  '5h 10m',
#  '21h 50m',
#  '16h 00m',
#  '9h 40m',
#  '8h 55m',
#  '18h 30m',
#  '27h 05m',
#  '31h 30m',
#  '9h 10m',
#  '17h 30m',
#  '1h 20m',
#  '10h 55m',
#  '15h 10m',
#  '4h 45m',
#  '6h 50m',
#  '7h 50m',
#  '6h 35m',
#  '15h 15m',
#  '13h 15m',
#  '12h 35m',
#  '8h 35m',
#  '16h 35m',
#  '17h 35m',
#  '11h 40m',
#  '1h 20m',
#  '14h 35m',
#  '11h 45m',
#  '12h 50m',
#  '14h 15m',
#  '15h 05m',
#  '13h 45m',
#  '14h 50m',
#  '19h 30m',
#  '15h 45m',
#  '25h 35m',
#  '25h 35m',
#  '21h 50m',
#  '30h 10m',
#  '19h 30m',
#  '22h 00m',
#  '23h 00m',
#  '25h 35m',
# ...

# %% [markdown]
# # total stops

# %%
#SCRAPPING total stops
stops = driver.find_elements_by_xpath("//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']")
stops
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="72b26f52-868b-4d02-b6d3-71aa9eadba7d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="27adaaa4-eb2e-447f-a5a1-de6d4e325b2b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="673742b9-fc76-4916-b136-91ccd9288dfb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="5731ae7c-6b5e-40d3-b264-db91f9322bb1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="8f07454e-fe74-47db-bfd4-b72d5009b850")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="f2276549-80f1-4340-962f-b27db7ab93e8")>,
# ...

# %% [markdown]
# # total stops

# %%
# looping the total stops
Total_stops = []

for i in stops:
    Total_stops.append(i.text)
Total_stops
# Out:
# ['Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '3 Stop(s)',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '3 Stop(s)',
#  '1 Stop',
#  '4 Stop(s)',
#  '4 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
# ...

# %% [markdown]
# # Price

# %%
#SCRAPPING Price
cost = driver.find_elements_by_xpath("//div[@class='i-b tipsy fare-summary-tooltip fs-18']")
cost
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="9a07b5e7-efe3-404b-bcc8-7bccb57febfb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="1714b39a-2de3-44b1-ace3-7cb336066e5c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="80027746-6f3b-461e-9954-3f185df4ae7f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="2d5b2c7c-3df3-4fed-82d0-dafdc9484b6f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="169cdacb-0c27-4e1d-b493-570386903619")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99ec03a3d8257045d134dd867d78a8ee", element="9d877179-c4e6-4bba-8a39-153edba9c4ed")>,
# ...

# %%
# looping the Price
Price = []

for i in cost:
    Price.append(i.text)
Price
# Out:
# ['1,890',
#  '2,019',
#  '2,019',
#  '2,019',
#  '2,174',
#  '2,383',
#  '2,418',
#  '2,418',
#  '2,531',
#  '2,804',
#  '2,842',
#  '2,842',
#  '3,052',
#  '3,735',
#  '4,194',
#  '4,194',
#  '4,305',
#  '5,008',
#  '5,100',
#  '5,110',
#  '5,110',
#  '5,161',
#  '5,350',
#  '5,943',
#  '5,996',
#  '6,143',
#  '6,143',
#  '6,258',
#  '6,258',
#  '6,258',
#  '6,385',
#  '6,867',
#  '6,888',
#  '6,939',
#  '7,023',
#  '7,124',
#  '7,181',
#  '7,181',
#  '7,181',
#  '7,225',
#  '7,225',
#  '7,256',
#  '7,401',
#  '7,401',
#  '7,602',
#  '7,602',
#  '7,602',
#  '7,645',
#  '7,830',
#  '8,038',
#  '8,057',
#  '8,170',
#  '8,170',
#  '8,170',
#  '8,190',
#  '8,463',
#  '8,590',
#  '8,673',
#  '8,673',
#  '8,673',
#  '8,792',
#  '9,324',
#  '9,324',
#  '9,394',
#  '9,430',
#  '9,709',
#  '9,709',
#  '9,745',
#  '9,745',
#  '9,814',
#  '10,129',
#  '10,129',
#  '10,129',
#  '10,165',
#  '10,165',
#  '10,549',
#  '10,549',
#  '10,654',
#  '10,654',
#  '10,654',
#  '10,889',
#  '11,074',
# ...

# %%
# creating the dataframe for flight price prediction
df=pd.DataFrame({"Flight_name":Flight_name[0:],"Depart":Depart[0:],"Departure_Time":Departure_Time[0:],"Destination":Destination[0:],
                "Arrival_Time":Arrival_Time[0:],"Duration":Duration[0:],"Total_stops":Total_stops[0:],"Price":Price[0:]})
df
# Out:
#     Flight_name  Depart Departure_Time Destination    Arrival_Time Duration  \
# 0     Air India  Mumbai          21:00         Goa           22:35   1h 35m
# 1      Air Asia  Mumbai          23:35         Goa  00:35\n+ 1 day   1h 00m
# 2        IndiGo  Mumbai          00:25         Goa           01:35   1h 10m
# 3      SpiceJet  Mumbai          23:45         Goa  01:00\n+ 1 day   1h 15m
# 4      Go First  Mumbai          22:05         Goa           23:25   1h 20m
# ..          ...     ...            ...         ...             ...      ...
# 102     Vistara  Mumbai          06:30         Goa           13:50   7h 20m
# 103     Vistara  Mumbai          07:30         Goa           13:50   6h 20m
# 104   Air India  Mumbai          07:00         Goa           13:15   6h 15m
# 105    Air Asia  Mumbai          22:55         Goa  15:25\n+ 1 day  16h 30m
# 106    Air Asia  Mumbai          07:20         Goa           15:25   8h 05m
#
#     Total_stops   Price
# 0      Non Stop   1,890
# ...

# %%
df.to_csv("flightprice8",index=False)

# %% [markdown]
# # Banglore to kolkata

# %%
url="https://flight.yatra.com/air-search-ui/seodom/trigger?type=O&viewName=normal&flexi=0&noOfSegments=1&origin=BLR&originCountry=IN&destination=CCU&preferred=&destinationCountry=IN&flight_depart_date=21%2F12%2F2021&ADT=1&CHD=0&INF=0&class=Economy&source=seo"

# %%
driver.get(url)

# %% [markdown]
# # airline name

# %%
# SCRAPPING airline name
airline_name = driver.find_elements_by_xpath("//span[@class='i-b text ellipsis']")
airline_name
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="1cc8374b-1ef9-42b0-be90-6fa2d80b3cd8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="aea47862-66f3-4197-8f51-bce92bc0d8cd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="ef4b2869-cf29-40be-b94a-47be87569998")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="5b83694f-fa09-4465-ac69-7fe02da63450")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="ae045a68-86a0-4df4-b31e-3cbdcf53d307")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="e189fb11-4866-497d-925f-3e3fd8e8d83b")>,
# ...

# %%
# looping the airline_name
Flight_name = []

for i in airline_name:
    Flight_name.append(i.text)
Flight_name
# Out:
# ['IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Go First',
#  'Air Asia',
#  'Go First',
#  'IndiGo',
#  'Air Asia',
#  'IndiGo',
#  'IndiGo',
#  'Air Asia',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air Asia',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'Go First',
#  'Air Asia',
#  'SpiceJet',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'SpiceJet',
#  'SpiceJet',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air Asia',
#  'IndiGo',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'Go First',
#  'IndiGo',
#  'Go First',
#  'Go First',
#  'Go First',
#  'SpiceJet',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Go First',
#  'IndiGo',
# ...

# %% [markdown]
# # departure

# %%
#SCRAPPING departure
source = driver.find_elements_by_xpath("//p[@title='Bangalore']")
source
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="61063b35-1e7d-4595-a9a6-7b781da7d594")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="5348b19f-d25e-4f0a-bda0-1f1f6b510064")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="84faa9ae-7c30-47fd-a20b-c915915ea0ef")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="f13941f3-9e0f-4d19-a978-ea29d64c61ee")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="58f74f3a-d7d9-43af-9453-c16708660e1f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="ede91c92-4a66-4e8e-931f-501cfc974af7")>,
# ...

# %%
# looping the departure
Depart = []

for i in source:
    Depart.append(i.text)
Depart
# Out:
# ['Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
# ...

# %% [markdown]
# # destination

# %%
#SCRAPPING destination
destiny = driver.find_elements_by_xpath("//p[@title='Kolkata']")
destiny
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="5198a3cb-420c-46df-8ab2-71851eacb4eb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="975b24c5-e1b0-4def-9765-c0aa3968d1e1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="aacc0c61-62c1-46e2-9863-11d4a5d4040c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="9cd85326-471b-45c9-8f5f-84abe45a8455")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="24a6bbc7-5cb0-4657-ba5b-278e4485ca5b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="15378ea4-1695-4f19-a64d-f147ea28e56a")>,
# ...

# %%
# looping the destination
Destination = []

for i in destiny:
    Destination.append(i.text)
Destination
# Out:
# ['Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
# ...

# %% [markdown]
# # departure time

# %%
#SCRAPPING departure time
Dept_Time = driver.find_elements_by_xpath("//div[@class='i-b pr']")
Dept_Time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="ef326ded-49d3-4ceb-8516-4644843b081b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="99189b03-e7da-48ec-9e93-fb76c6d31c54")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="5a4b9df4-4204-46af-a33c-9c606edcf72d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="369a464c-44f6-4767-a3c3-35214def361b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="36fc13a0-adbf-4c68-bd9f-7f3b1c9dc26b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="281eff36-7734-4360-af73-454c308e66bb")>,
# ...

# %%
# looping the departure time
Departure_Time = []

for i in Dept_Time:
    Departure_Time.append(i.text)
Departure_Time
# Out:
# ['23:45',
#  '21:55',
#  '13:05',
#  '23:45',
#  '21:55',
#  '20:15',
#  '09:20',
#  '18:45',
#  '20:00',
#  '23:10',
#  '14:00',
#  '15:15',
#  '22:55',
#  '23:25',
#  '13:15',
#  '18:30',
#  '03:30',
#  '08:40',
#  '11:45',
#  '18:00',
#  '20:05',
#  '15:40',
#  '10:15',
#  '21:45',
#  '05:45',
#  '22:50',
#  '05:35',
#  '05:40',
#  '05:25',
#  '20:35',
#  '18:15',
#  '22:55',
#  '15:45',
#  '14:50',
#  '17:05',
#  '05:55',
#  '06:35',
#  '12:50',
#  '18:50',
#  '07:40',
#  '05:30',
#  '16:25',
#  '07:10',
#  '16:20',
#  '06:10',
#  '13:05',
#  '12:50',
#  '22:55',
#  '11:50',
#  '19:10',
#  '06:45',
#  '19:10',
#  '08:30',
#  '08:30',
#  '07:00',
#  '16:55',
#  '22:00',
#  '20:00',
#  '08:10',
#  '11:00',
#  '21:40',
#  '19:55',
#  '18:25',
#  '21:40',
#  '09:30',
#  '08:30',
#  '06:40',
#  '21:40',
#  '19:55',
#  '08:15',
#  '10:45',
#  '06:45',
#  '05:45',
#  '10:25',
#  '05:45',
#  '11:30',
#  '21:00',
#  '17:20',
#  '15:30',
#  '21:00',
#  '07:40',
#  '00:45',
#  '00:10',
# ...

# %% [markdown]
# # arrival time

# %%
#SCRAPPING arrival time
Arr_Time = driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
Arr_Time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="d59e172d-ea0a-441d-9053-259405427d15")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="fbdfcc32-3e0c-4d05-97f9-af6632278e0e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="329ba9fc-fbd0-454b-a181-4ca7e636fffc")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="eda8187c-352b-471a-bb39-11da37fe4563")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="681f0059-0964-4456-9e75-988ae23ca41d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="841a0c5b-23b5-4b0f-bc6e-4003cfdc802f")>,
# ...

# %%
# looping the arrival time
Arrival_Time = []

for i in Arr_Time:
    Arrival_Time.append(i.text)
Arrival_Time
# Out:
# ['07:55\n+ 1 day',
#  '07:55\n+ 1 day',
#  '19:15',
#  '06:05\n+ 1 day',
#  '06:05\n+ 1 day',
#  '06:05\n+ 1 day',
#  '19:15',
#  '06:05\n+ 1 day',
#  '22:20',
#  '01:35\n+ 1 day',
#  '16:30',
#  '17:45',
#  '01:25\n+ 1 day',
#  '01:55\n+ 1 day',
#  '15:50',
#  '21:05',
#  '06:10',
#  '11:20',
#  '14:25',
#  '20:40',
#  '22:45',
#  '19:20',
#  '19:15',
#  '00:10\n+ 1 day',
#  '08:20',
#  '07:55\n+ 1 day',
#  '08:05',
#  '20:50',
#  '14:35',
#  '07:25\n+ 1 day',
#  '00:10\n+ 1 day',
#  '07:15\n+ 1 day',
#  '00:10\n+ 1 day',
#  '00:10\n+ 1 day',
#  '19:35',
#  '08:30',
#  '09:15',
#  '22:55',
#  '08:05\n+ 1 day',
#  '12:55',
#  '12:55',
#  '01:05\n+ 1 day',
#  '13:20',
#  '22:40',
#  '13:20',
#  '22:40',
#  '19:00',
#  '08:15\n+ 1 day',
#  '13:55\n+ 1 day',
#  '08:50\n+ 1 day',
#  '08:50\n+ 1 day',
#  '23:15\n+ 1 day',
#  '17:25',
#  '20:15',
#  '17:25',
#  '21:50',
#  '07:30\n+ 1 day',
#  '07:30\n+ 1 day',
#  '23:50',
#  '11:40\n+ 1 day',
#  '09:45\n+ 1 day',
#  '09:45\n+ 1 day',
# ...

# %% [markdown]
# # duration

# %%
#SCRAPPING duration
Dur = driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
Dur
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="2556eadc-7512-426a-b308-03b179b8da83")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="9a2e4bd1-7b5e-47ba-853c-c18186ea0508")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="6c9a99b6-5e02-48c1-9528-a9e425bdba7d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="5b11329a-e9f4-4dfd-a350-a743cde21c9b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="41c53c9a-616b-4d0d-86eb-9dcef09146b5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="1fec7970-d4c6-4da5-bc06-122d5800a4c3")>,
# ...

# %%
# looping the duration
Duration = []

for i in Dur:
    Duration.append(i.text)
Duration
# Out:
# ['8h 10m',
#  '10h 00m',
#  '6h 10m',
#  '6h 20m',
#  '8h 10m',
#  '9h 50m',
#  '9h 55m',
#  '11h 20m',
#  '2h 20m',
#  '2h 25m',
#  '2h 30m',
#  '2h 30m',
#  '2h 30m',
#  '2h 30m',
#  '2h 35m',
#  '2h 35m',
#  '2h 40m',
#  '2h 40m',
#  '2h 40m',
#  '2h 40m',
#  '2h 40m',
#  '3h 40m',
#  '9h 00m',
#  '2h 25m',
#  '2h 35m',
#  '9h 05m',
#  '2h 30m',
#  '15h 10m',
#  '9h 10m',
#  '10h 50m',
#  '5h 55m',
#  '8h 20m',
#  '8h 25m',
#  '9h 20m',
#  '2h 30m',
#  '2h 35m',
#  '2h 40m',
#  '10h 05m',
#  '13h 15m',
#  '5h 15m',
#  '7h 25m',
#  '8h 40m',
#  '6h 10m',
#  '6h 20m',
#  '7h 10m',
#  '9h 35m',
#  '6h 10m',
#  '9h 20m',
#  '26h 05m',
#  '13h 40m',
#  '26h 05m',
#  '28h 05m',
#  '8h 55m',
#  '11h 45m',
#  '10h 25m',
#  '4h 55m',
#  '9h 30m',
#  '11h 30m',
#  '15h 40m',
#  '24h 40m',
#  '12h 05m',
#  '13h 50m',
#  '15h 20m',
#  '22h 15m',
#  '7h 25m',
#  '8h 25m',
#  '10h 15m',
#  '19h 15m',
#  '21h 00m',
#  '13h 55m',
#  '10h 10m',
#  '16h 30m',
#  '8h 45m',
#  '11h 55m',
# ...

# %% [markdown]
# # total stops

# %%
#SCRAPPING total stops
stops = driver.find_elements_by_xpath("//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']")
stops
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="a837a2a4-8e82-418b-a748-8b7cbf9fabea")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="a20cbb14-d0ac-4ee9-a0d1-a2c2b3edf3df")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="a66a3a5c-b76b-41a4-a386-44daf52450b9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="d57c2399-f376-4e01-8045-a7370b0fd324")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="4f3c3a62-34e8-4169-876d-39d8ad0cc6b3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="5c947429-38a3-4621-9bbe-53dff2bd18a9")>,
# ...

# %%
# looping the total stops
Total_stops = []

for i in stops:
    Total_stops.append(i.text)
Total_stops
# Out:
# ['1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
# ...

# %% [markdown]
# # Price

# %%
#SCRAPPING Price
cost = driver.find_elements_by_xpath("//div[@class='i-b tipsy fare-summary-tooltip fs-18']")
cost
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="a8378b7a-500f-4d9f-b453-b44494a78b25")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="227c1fe0-2e5e-4604-bc97-5981212f4ab9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="c9273f65-8ef7-404a-99a8-49dda7bf065a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="a22d252a-d6a3-4adb-8aa5-cf9b9f2f8321")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="ec114f9e-96ec-400c-b59e-7126293ae473")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="1a708937-2b66-47c6-b16f-53dbbdb9b869")>,
# ...

# %%
# looping the Price
Price = []

for i in cost:
    Price.append(i.text)
Price
# Out:
# ['3,234',
#  '3,234',
#  '3,582',
#  '3,582',
#  '3,582',
#  '3,582',
#  '3,582',
#  '3,582',
#  '3,597',
#  '3,597',
#  '3,597',
#  '3,597',
#  '3,597',
#  '3,597',
#  '3,597',
#  '3,597',
#  '3,597',
#  '3,597',
#  '3,597',
#  '3,597',
#  '3,597',
#  '3,597',
#  '3,843',
#  '3,912',
#  '3,918',
#  '3,930',
#  '3,981',
#  '4,056',
#  '4,163',
#  '4,163',
#  '4,177',
#  '4,177',
#  '4,177',
#  '4,177',
#  '4,225',
#  '4,225',
#  '4,226',
#  '4,377',
#  '4,434',
#  '4,448',
#  '4,448',
#  '4,448',
#  '4,476',
#  '4,476',
#  '4,476',
#  '4,476',
#  '4,551',
#  '5,285',
#  '5,478',
#  '5,536',
#  '5,536',
#  '5,536',
#  '5,583',
#  '5,583',
#  '5,902',
#  '6,117',
#  '6,188',
#  '6,188',
#  '6,188',
#  '6,437',
#  '6,545',
#  '6,545',
#  '6,545',
#  '6,545',
#  '6,646',
#  '6,646',
#  '6,646',
#  '6,646',
#  '6,646',
#  '6,697',
#  '6,858',
#  '6,882',
#  '7,004',
#  '7,004',
#  '7,004',
#  '7,013',
#  '7,109',
#  '7,529',
#  '7,571',
#  '7,678',
#  '7,678',
#  '7,730',
#  '7,730',
# ...

# %%
# creating the dataframe for flight price prediction
df=pd.DataFrame({"Flight_name":Flight_name[0:],"Depart":Depart[0:],"Departure_Time":Departure_Time[0:],"Destination":Destination[0:],
                "Arrival_Time":Arrival_Time[0:],"Duration":Duration[0:],"Total_stops":Total_stops[0:],"Price":Price[0:]})
df
# Out:
#     Flight_name     Depart Departure_Time Destination    Arrival_Time  \
# 0        IndiGo  Bangalore          23:45     Kolkata  07:55\n+ 1 day
# 1        IndiGo  Bangalore          21:55     Kolkata  07:55\n+ 1 day
# 2        IndiGo  Bangalore          13:05     Kolkata           19:15
# 3        IndiGo  Bangalore          23:45     Kolkata  06:05\n+ 1 day
# 4        IndiGo  Bangalore          21:55     Kolkata  06:05\n+ 1 day
# ..          ...        ...            ...         ...             ...
# 121     Vistara  Bangalore          10:15     Kolkata           19:35
# 122   Air India  Bangalore          21:00     Kolkata  16:05\n+ 1 day
# 123   Air India  Bangalore          17:20     Kolkata  16:05\n+ 1 day
# 124   Air India  Bangalore          10:25     Kolkata  16:05\n+ 1 day
# 125     Vistara  Bangalore          12:20     Kolkata           22:45
#
#     Duration Total_stops   Price
# 0     8h 10m      1 Stop   3,234
# 1    10h 00m      1 Stop   3,234
# ...

# %%
df.to_csv("flightprice9",index=False)

# %% [markdown]
# # Bangalore to Jaipur

# %%
url="https://flight.yatra.com/air-search-ui/seodom/trigger?type=O&viewName=normal&flexi=0&noOfSegments=1&origin=BLR&originCountry=IN&destination=JAI&preferred=&destinationCountry=IN&flight_depart_date=03%2F01%2F2022&ADT=1&CHD=0&INF=0&class=Economy&source=seo"

# %%
driver.get(url)

# %% [markdown]
# # airline name

# %%
# SCRAPPING airline name
airline_name = driver.find_elements_by_xpath("//span[@class='i-b text ellipsis']")
airline_name
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="95c8e2d4-2ba0-41db-8504-4c6017e900c2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="3a078f8c-ab20-444b-bfcd-f6ee36fc6087")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="aeed97ff-db50-4999-a8d6-6875c4181158")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="f58d9080-58a1-47b3-97be-5b142f8af694")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="678c9753-e9c1-4b09-b1df-4b726ebf8680")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="de20ccbe-450d-48ee-9de9-362b328ff4dd")>,
# ...

# %%
# looping the airline_name
Flight_name = []

for i in airline_name:
    Flight_name.append(i.text)
Flight_name
# Out:
# ['Air India',
#  'Go First',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Go First',
#  'Go First',
#  'Air Asia',
#  'Air Asia',
#  'Air India',
#  'Air India',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Go First',
#  'Go First',
#  'Air Asia',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air Asia',
#  'Air Asia',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'IndiGo',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
# ...

# %% [markdown]
# # departure

# %%
#SCRAPPING departure
source = driver.find_elements_by_xpath("//p[@title='Bangalore']")
source
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="2c035403-5c1f-4c6d-bb6c-b727f903c712")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="fe2b52dc-1936-49d2-80ae-12ed034d18a4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="91764ccc-847f-4965-95a9-0f606ab1049c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="782f4480-925c-404b-84de-7b9b241e92c6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="b3bb1361-c84e-4127-88c8-acb7f9f59fac")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="2b4b1760-30cc-404a-b084-5689afa1ffd4")>,
# ...

# %%
# looping the departure
Depart = []

for i in source:
    Depart.append(i.text)
Depart
# Out:
# ['Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
# ...

# %% [markdown]
# # destination

# %%
#SCRAPPING destination
destiny = driver.find_elements_by_xpath("//p[@title='Jaipur']")
destiny
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="60d60aa0-3d05-4fa4-8c16-f7da76b0de0d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="6a5e921a-8b0b-472d-a1c2-0fbe1ae97d3e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="c9ead983-25a7-4d61-8416-b51a1dac9fda")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="c91b6326-57c7-48b3-8704-dc19b262187b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="4b23fbd5-8348-47cc-9483-44dc1ceebf34")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="c25bc627-857e-48b9-947f-04126a85bd2c")>,
# ...

# %%
# looping the destination
Destination = []

for i in destiny:
    Destination.append(i.text)
Destination
# Out:
# ['Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
# ...

# %% [markdown]
# # departure time

# %%
#SCRAPPING departure time
Dept_Time = driver.find_elements_by_xpath("//div[@class='i-b pr']")
Dept_Time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="de22bff8-c451-434f-9cab-3d00dc3ac9ed")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="7e9468ab-2adb-4b3c-9870-953e10dfc53e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="0ffa8ed5-ce0e-445b-bfb0-dacf09f6405c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="227b9a6d-0540-4d00-af9e-4f38963b8c59")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="edee88e0-99bd-4332-995f-ef3f75195748")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="dc67d001-a85a-421f-a085-68554316d054")>,
# ...

# %%
# looping the departure time
Departure_Time = []

for i in Dept_Time:
    Departure_Time.append(i.text)
Departure_Time
# Out:
# ['07:00',
#  '08:15',
#  '07:40',
#  '13:00',
#  '15:35',
#  '21:50',
#  '18:55',
#  '15:20',
#  '08:55',
#  '22:00',
#  '20:00',
#  '05:30',
#  '05:35',
#  '06:45',
#  '19:10',
#  '07:30',
#  '22:50',
#  '08:10',
#  '05:45',
#  '07:30',
#  '05:35',
#  '04:50',
#  '05:50',
#  '05:50',
#  '11:20',
#  '06:10',
#  '21:00',
#  '17:50',
#  '13:20',
#  '10:25',
#  '07:35',
#  '07:35',
#  '04:50',
#  '18:50',
#  '19:10',
#  '19:10',
#  '06:45',
#  '06:45',
#  '06:45',
#  '18:50',
#  '15:15',
#  '06:45',
#  '14:00',
#  '13:20',
#  '10:25',
#  '21:00',
#  '17:50',
#  '06:10',
#  '13:20',
#  '10:25',
#  '21:00',
#  '06:10',
#  '17:50',
#  '06:45',
#  '06:45',
#  '06:45',
#  '07:10',
#  '13:05',
#  '07:35',
#  '20:15',
#  '17:15',
#  '21:00',
#  '21:00',
#  '17:50',
#  '17:50',
#  '00:40',
#  '10:30',
#  '07:50',
#  '06:40',
#  '10:55',
#  '09:10',
#  '05:40',
#  '16:20',
#  '06:10',
#  '09:50',
#  '12:40',
#  '04:30',
#  '16:50',
#  '08:05',
#  '12:40',
#  '21:45',
#  '19:50',
#  '16:30',
# ...

# %% [markdown]
# # arrival time

# %%
#SCRAPPING arrival time
Arr_Time = driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
Arr_Time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="1ae85af0-d77f-4489-b676-f60e6c96d9e4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="2b23fdb2-9fda-4023-8b2b-89094a8132e0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="1684fd14-b902-429d-88ff-6537bac9ef90")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="c2952348-8316-4d2d-b4a3-618015ea0868")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="d29beefe-a3ef-4878-a6c1-edafb66ad16b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="af402893-79cd-4b78-8b7d-6187df0962e7")>,
# ...

# %%
# looping the arrival time
Arrival_Time = []

for i in Arr_Time:
    Arrival_Time.append(i.text)
Arrival_Time
# Out:
# ['09:20',
#  '10:45',
#  '11:20',
#  '16:45',
#  '19:40',
#  '00:25\n+ 1 day',
#  '21:35',
#  '18:00',
#  '11:45',
#  '07:55\n+ 1 day',
#  '07:55\n+ 1 day',
#  '11:20',
#  '09:50',
#  '13:15',
#  '13:15\n+ 1 day',
#  '12:40',
#  '12:40\n+ 1 day',
#  '21:15',
#  '21:15',
#  '19:40',
#  '19:50',
#  '19:50',
#  '12:10',
#  '21:00',
#  '23:20',
#  '14:00',
#  '12:55\n+ 1 day',
#  '12:55\n+ 1 day',
#  '12:55\n+ 1 day',
#  '12:55\n+ 1 day',
#  '12:55\n+ 1 day',
#  '12:55\n+ 1 day',
#  '09:50',
#  '09:50\n+ 1 day',
#  '12:55\n+ 1 day',
#  '12:55\n+ 1 day',
#  '12:55\n+ 1 day',
#  '12:55\n+ 1 day',
#  '12:55\n+ 1 day',
#  '12:55\n+ 1 day',
#  '12:55\n+ 1 day',
#  '12:55\n+ 1 day',
#  '22:50',
#  '20:00',
#  '20:00',
#  '07:10\n+ 1 day',
#  '07:10\n+ 1 day',
#  '20:00',
#  '07:10\n+ 1 day',
#  '07:10\n+ 1 day',
#  '20:00\n+ 1 day',
#  '07:10\n+ 1 day',
#  '20:00\n+ 1 day',
#  '12:55\n+ 1 day',
#  '12:55\n+ 1 day',
#  '12:55\n+ 1 day',
#  '13:45',
#  '22:20',
#  '20:00',
#  '02:35\n+ 1 day',
# ...

# %% [markdown]
# # duration

# %%
#SCRAPPING duration
Dur = driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
Dur
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="b175447d-5fbd-477e-a337-c48da16d50b2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="4461c348-bda6-4c8f-a131-c33b54354d72")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="7f7cda7e-72a3-4aa8-a42f-1bcd9b26b53b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="06781456-984b-4cd8-86c8-0c20b1228306")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="bb516593-7eb4-4612-be8d-febd6b690b1c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="cf779c22-6eac-4914-b000-a48fe8eb3e2f")>,
# ...

# %%
# looping the duration
Duration = []

for i in Dur:
    Duration.append(i.text)
Duration
# Out:
# ['2h 20m',
#  '2h 30m',
#  '3h 40m',
#  '3h 45m',
#  '4h 05m',
#  '2h 35m',
#  '2h 40m',
#  '2h 40m',
#  '2h 50m',
#  '9h 55m',
#  '11h 55m',
#  '5h 50m',
#  '4h 15m',
#  '6h 30m',
#  '18h 05m',
#  '5h 10m',
#  '13h 50m',
#  '13h 05m',
#  '15h 30m',
#  '12h 10m',
#  '14h 15m',
#  '15h 00m',
#  '6h 20m',
#  '15h 10m',
#  '12h 00m',
#  '7h 50m',
#  '15h 55m',
#  '19h 05m',
#  '23h 35m',
#  '26h 30m',
#  '29h 20m',
#  '29h 20m',
#  '5h 00m',
#  '15h 00m',
#  '17h 45m',
#  '17h 45m',
#  '30h 10m',
#  '30h 10m',
#  '30h 10m',
#  '18h 05m',
#  '21h 40m',
#  '30h 10m',
#  '8h 50m',
#  '6h 40m',
#  '9h 35m',
#  '10h 10m',
#  '13h 20m',
#  '13h 50m',
#  '17h 50m',
#  '20h 45m',
#  '23h 00m',
#  '25h 00m',
#  '26h 10m',
#  '30h 10m',
#  '30h 10m',
#  '30h 10m',
#  '6h 35m',
#  '9h 15m',
#  '12h 25m',
#  '6h 20m',
#  '9h 20m',
#  '16h 15m',
#  '16h 15m',
#  '19h 25m',
#  '19h 25m',
#  '4h 50m',
#  '8h 00m',
#  '6h 00m',
#  '7h 10m',
#  '8h 05m',
#  '9h 50m',
#  '6h 45m',
#  '6h 00m',
# ...

# %% [markdown]
# # total stops

# %%
#SCRAPPING total stops
stops = driver.find_elements_by_xpath("//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']")
stops
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="09b1fc58-e855-44fa-829e-eac290207fc8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="523990df-571d-4b9b-ac25-c36c7acdb18d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="379561c5-594d-48cd-8ed4-320b439fa656")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="94ab614e-5eee-4b24-9a75-bb4dc672159f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="81986996-8e8d-47be-873e-19383caf9edd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="e916e0ba-22de-437d-b742-1a41793ae2ab")>,
# ...

# %%
# looping the total stops
Total_stops = []

for i in stops:
    Total_stops.append(i.text)
Total_stops
# Out:
# ['Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '3 Stop(s)',
#  '2 Stop(s)',
#  '3 Stop(s)',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
# ...

# %% [markdown]
# # Price

# %%
#SCRAPPING Price
cost = driver.find_elements_by_xpath("//div[@class='i-b tipsy fare-summary-tooltip fs-18']")
cost
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="812b6ee8-514d-4d73-b6c0-64136c7243e9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="4c68c8e1-8380-49b3-a137-19bfad192237")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="e3a56daa-f5a2-4382-96df-e09e99f5dfc7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="b44b1c3e-9583-4b45-ae86-c1bfa4264ae9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="ba53e138-563c-41d6-8562-c884e8782fc8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2be1a3eb2317b9c7187cdd62ed56ca2d", element="36bf64b2-1f5f-4d1b-80e2-de3c01bb64fc")>,
# ...

# %%
# looping the Price
Price = []

for i in cost:
    Price.append(i.text)
Price
# Out:
# ['3,294',
#  '3,294',
#  '3,295',
#  '3,295',
#  '3,295',
#  '3,971',
#  '3,971',
#  '4,151',
#  '4,151',
#  '4,373',
#  '4,373',
#  '4,382',
#  '4,385',
#  '4,591',
#  '4,591',
#  '4,653',
#  '4,653',
#  '4,845',
#  '4,845',
#  '5,038',
#  '5,215',
#  '5,215',
#  '5,217',
#  '5,217',
#  '5,582',
#  '5,583',
#  '5,583',
#  '5,583',
#  '5,583',
#  '5,583',
#  '5,606',
#  '5,606',
#  '5,744',
#  '5,744',
#  '5,806',
#  '5,806',
#  '5,806',
#  '5,806',
#  '5,806',
#  '5,827',
#  '5,827',
#  '6,121',
#  '6,324',
#  '6,539',
#  '6,539',
#  '6,539',
#  '6,539',
#  '6,539',
#  '6,539',
#  '6,539',
#  '6,539',
#  '6,539',
#  '6,539',
#  '6,541',
#  '6,541',
#  '6,541',
#  '6,996',
#  '6,996',
#  '7,479',
#  '8,247',
#  '8,247',
#  '8,541',
#  '8,541',
#  '8,541',
#  '8,541',
#  '9,011',
#  '9,429',
#  '9,693',
#  '9,693',
#  '10,115',
#  '10,115',
#  '10,221',
#  '10,283',
#  '10,283',
#  '10,638',
#  '11,109',
#  '11,109',
#  '11,109',
#  '11,109',
#  '11,109',
#  '11,216',
#  '11,216',
# ...

# %%
# creating the dataframe for flight price prediction
df=pd.DataFrame({"Flight_name":Flight_name[0:],"Depart":Depart[0:],"Departure_Time":Departure_Time[0:],"Destination":Destination[0:],
                "Arrival_Time":Arrival_Time[0:],"Duration":Duration[0:],"Total_stops":Total_stops[0:],"Price":Price[0:]})
df
# Out:
#    Flight_name     Depart Departure_Time Destination    Arrival_Time Duration  \
# 0    Air India  Bangalore          07:00      Jaipur           09:20   2h 20m
# 1     Go First  Bangalore          08:15      Jaipur           10:45   2h 30m
# 2     Air Asia  Bangalore          07:40      Jaipur           11:20   3h 40m
# 3     Air Asia  Bangalore          13:00      Jaipur           16:45   3h 45m
# 4     Air Asia  Bangalore          15:35      Jaipur           19:40   4h 05m
# ..         ...        ...            ...         ...             ...      ...
# 87      IndiGo  Bangalore          23:35      Jaipur  07:05\n+ 1 day   7h 30m
# 88      IndiGo  Bangalore          22:10      Jaipur  07:05\n+ 1 day   8h 55m
# 89      IndiGo  Bangalore          23:35      Jaipur  08:30\n+ 1 day   8h 55m
# 90      IndiGo  Bangalore          04:40      Jaipur           13:50   9h 10m
# 91      IndiGo  Bangalore          22:10      Jaipur  08:30\n+ 1 day  10h 20m
#
#    Total_stops   Price
# ...

# %%
df.to_csv("flightprice10",index=False)

# %% [markdown]
# # Bangalore to Lucknow

# %%
url = "https://flight.yatra.com/air-search-ui/seodom/trigger?type=O&viewName=normal&flexi=0&noOfSegments=1&origin=BLR&originCountry=IN&destination=LKO&preferred=&destinationCountry=IN&flight_depart_date=01%2F12%2F2021&ADT=1&CHD=0&INF=0&class=Economy&source=seo"

# %%
driver.get(url)

# %% [markdown]
# # airline name

# %%
# SCRAPPING airline_name
airline_name = driver.find_elements_by_xpath("//span[@class='i-b text ellipsis']")
airline_name
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="560bc221-b85b-4caa-b322-fcfe997e377c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="1d4517de-d44e-43c9-9548-6dca3a7b9510")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="4b7409b6-7c37-41eb-8507-558c866ea921")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="de025e2d-47b8-4be1-bdaf-a3d81b8b8ffe")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="66859586-f47f-4081-badc-4e5f876c6f2e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="0adfad3b-8783-4661-b340-171289446a0d")>,
# ...

# %%
# looping the airline_name
Flight_name = []

for i in airline_name:
    Flight_name.append(i.text)
Flight_name
# Out:
# ['IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Air India',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Air India',
#  'Air India',
#  'Vistara',
#  'Vistara',
#  'Air India',
#  'Vistara',
#  'Vistara',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Go First',
#  'Go First',
#  'IndiGo',
# ...

# %% [markdown]
# # departure

# %%
#SCRAPPING departure
source = driver.find_elements_by_xpath("//p[@title='Bangalore']")
source
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="4d7e7ef2-38b8-408d-ac4e-17a1fa5989dc")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="86f411ff-bff8-4fa6-b831-c3e3e7da91a8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="93b3e856-3bb9-46b2-be9a-ddd433ee6fca")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="798912ff-1fc1-4d87-a8a5-7640101c5e8e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="15b63a34-4647-4f2f-b898-398e0b869bf2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="a1a63867-07d2-40c5-a218-84aa2b2f3982")>,
# ...

# %%
# looping the departure
Depart = []

for i in source:
    Depart.append(i.text)
Depart
# Out:
# ['Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
# ...

# %% [markdown]
# ## destination

# %%
#SCRAPPING destination
destiny = driver.find_elements_by_xpath("//p[@title='Lucknow']")
destiny
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="2c043bac-b06e-4364-9fd9-a1e3705e9783")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="bb4f446c-5f55-4b31-813e-0abc4d46c379")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="dc75f165-8ef0-4501-92f8-b7a28f4b56fa")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="b4743bb3-e3c3-4aeb-be78-b0be164401fc")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="e5846003-bada-4770-ac6b-3b813079129c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="43180de8-d160-45a0-ad71-206fa6fc4121")>,
# ...

# %%
# looping the destination
Destination = []

for i in destiny:
    Destination.append(i.text)
Destination
# Out:
# ['Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
# ...

# %% [markdown]
# # departure time

# %%
#SCRAPPING departure time
Dept_Time = driver.find_elements_by_xpath("//div[@class='i-b pr']")
Dept_Time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="076b6349-3f01-4128-8305-7a28dcec6389")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="51db9000-2ef8-4239-b179-1abc130c6333")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="c1502fd5-408c-4540-bf26-d8fa74856556")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="9b08cda2-72d0-4c8c-ae5d-b628808dca1c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="b04e2c36-a169-45ba-a6d3-fc8795d51db2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="05a3541f-223a-4dfd-9982-f60cdef27eeb")>,
# ...

# %%
# looping the departure time
Departure_Time = []

for i in Dept_Time:
    Departure_Time.append(i.text)
Departure_Time
# Out:
# ['06:20',
#  '17:55',
#  '06:35',
#  '13:15',
#  '11:45',
#  '21:00',
#  '21:00',
#  '12:10',
#  '07:05',
#  '11:20',
#  '09:05',
#  '06:30',
#  '05:45',
#  '21:00',
#  '07:40',
#  '21:00',
#  '07:40',
#  '11:00',
#  '19:10',
#  '06:45',
#  '06:10',
#  '09:20',
#  '07:10',
#  '17:50',
#  '16:45',
#  '14:00',
#  '07:50',
#  '23:35',
#  '09:30',
#  '06:40',
#  '23:35',
#  '22:10',
#  '11:55',
#  '07:50',
#  '22:10',
#  '23:35',
#  '21:10',
#  '07:00',
#  '12:40',
#  '12:40',
#  '07:00',
#  '21:10',
#  '19:40',
#  '09:45',
#  '08:00',
#  '09:45',
#  '08:00',
#  '19:40',
#  '06:45',
#  '06:45',
#  '17:45',
#  '11:30',
#  '17:50',
#  '17:45',
#  '11:30',
#  '16:30',
#  '14:00',
#  '10:30',
#  '19:55',
#  '18:25',
#  '18:25',
#  '13:20',
#  '10:25',
#  '06:10',
#  '19:10',
#  '06:45',
#  '06:45',
#  '07:30',
#  '22:50',
#  '10:15',
#  '19:25',
#  '19:25',
#  '23:30',
#  '08:10',
#  '08:10',
#  '22:00',
#  '13:20',
#  '10:25',
#  '06:10',
#  '05:45',
#  '19:10',
#  '06:45',
#  '06:40',
# ...

# %% [markdown]
# # arrival time

# %%
#SCRAPPING arrival time
Arr_Time = driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
Arr_Time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="cfe46dc4-1404-4a34-b0b7-dab6e6a60935")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="788774e8-f273-4c39-929a-63c01d75f14e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="b8d6b7b3-db20-48cb-9079-bf7018a65b59")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="f3aa9176-239c-44c7-aac1-d1ef605ed9e6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="17ac2733-3d40-4033-a09c-f135f0e8921c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="2249b484-95b7-474c-a868-8d859a40b0a5")>,
# ...

# %%
# looping the arrival time
Arrival_Time = []

for i in Arr_Time:
    Arrival_Time.append(i.text)
Arrival_Time
# Out:
# ['08:55',
#  '20:25',
#  '13:20',
#  '20:10',
#  '20:10',
#  '08:15\n+ 1 day',
#  '19:40\n+ 1 day',
#  '14:40',
#  '13:25',
#  '16:00',
#  '16:00',
#  '14:50',
#  '17:40',
#  '07:00\n+ 1 day',
#  '17:55',
#  '10:15\n+ 1 day',
#  '22:15',
#  '13:20',
#  '10:30\n+ 1 day',
#  '10:30\n+ 1 day',
#  '10:55',
#  '15:30',
#  '15:30',
#  '08:15\n+ 1 day',
#  '22:35',
#  '20:00',
#  '14:25',
#  '06:10\n+ 1 day',
#  '16:10',
#  '14:25',
#  '07:20\n+ 1 day',
#  '06:10\n+ 1 day',
#  '20:00',
#  '16:10',
#  '07:20\n+ 1 day',
#  '08:50\n+ 1 day',
#  '08:40\n+ 1 day',
#  '08:40\n+ 1 day',
#  '18:00',
#  '21:50',
#  '14:50',
#  '14:50\n+ 1 day',
#  '08:40\n+ 1 day',
#  '08:40\n+ 1 day',
#  '08:40\n+ 1 day',
#  '14:50',
#  '14:50',
#  '14:50\n+ 1 day',
#  '08:15\n+ 1 day',
#  '08:15\n+ 1 day',
#  '08:40\n+ 1 day',
#  '08:40\n+ 1 day',
#  '19:40\n+ 1 day',
#  '14:50\n+ 1 day',
#  '14:50\n+ 1 day',
#  '22:25',
#  '22:25',
#  '18:00',
#  '08:40\n+ 1 day',
#  '08:40\n+ 1 day',
#  '08:40\n+ 1 day',
# ...

# %% [markdown]
# # duration

# %%
#SCRAPPING duration
Dur = driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
Dur
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="771011fd-d187-432e-8899-130fe6265082")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="bf73c8df-11c5-4c6a-8876-8f45d6bb3693")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="bda2addd-7c0b-4c29-8672-6a0af38699ef")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="c1745a27-2c71-49ec-83ce-1da9e7914259")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="a608bbd3-7004-47b7-99ec-6551d9928e77")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="73faa8f8-2d57-4e26-bf2f-5a7158beae1c")>,
# ...

# %%
# looping the duration
Duration = []

for i in Dur:
    Duration.append(i.text)
Duration
# Out:
# ['2h 35m',
#  '2h 30m',
#  '6h 45m',
#  '6h 55m',
#  '8h 25m',
#  '11h 15m',
#  '22h 40m',
#  '2h 30m',
#  '6h 20m',
#  '4h 40m',
#  '6h 55m',
#  '8h 20m',
#  '11h 55m',
#  '10h 00m',
#  '10h 15m',
#  '13h 15m',
#  '14h 35m',
#  '2h 20m',
#  '15h 20m',
#  '27h 45m',
#  '4h 45m',
#  '6h 10m',
#  '8h 20m',
#  '14h 25m',
#  '5h 50m',
#  '6h 00m',
#  '6h 35m',
#  '6h 35m',
#  '6h 40m',
#  '7h 45m',
#  '7h 45m',
#  '8h 00m',
#  '8h 05m',
#  '8h 20m',
#  '9h 10m',
#  '9h 15m',
#  '11h 30m',
#  '25h 40m',
#  '5h 20m',
#  '9h 10m',
#  '7h 50m',
#  '17h 40m',
#  '13h 00m',
#  '22h 55m',
#  '24h 40m',
#  '5h 05m',
#  '6h 50m',
#  '19h 10m',
#  '25h 30m',
#  '25h 30m',
#  '14h 55m',
#  '21h 10m',
#  '25h 50m',
#  '21h 05m',
#  '27h 20m',
#  '5h 55m',
#  '8h 25m',
#  '7h 30m',
#  '12h 45m',
#  '14h 15m',
#  '14h 15m',
#  '18h 55m',
#  '21h 50m',
#  '26h 05m',
#  '24h 30m',
#  '36h 55m',
#  '36h 55m',
#  '5h 35m',
#  '14h 15m',
#  '5h 15m',
#  '19h 25m',
#  '19h 25m',
#  '7h 40m',
#  '9h 30m',
# ...

# %% [markdown]
# # total stops

# %%
#SCRAPPING total stops
stops = driver.find_elements_by_xpath("//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']")
stops
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="29825a16-ade8-493c-93c5-dded0f2e6a86")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="3430422e-c332-4e9d-86f1-2cc3ba7f03ec")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="7682feec-8c96-4dcf-94b7-fd00c864b322")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="8cbf8470-5fae-4107-8cb5-ec27162626fb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="7afd3660-bc5f-43a4-b3a4-741e7afa7a16")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="9f36d0ca-7eb3-4d2a-8c5f-4e76875dec25")>,
# ...

# %%
# looping the total stops
Total_stops = []

for i in stops:
    Total_stops.append(i.text)
Total_stops
# Out:
# ['Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '3 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '3 Stop(s)',
#  '3 Stop(s)',
#  '3 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
# ...

# %% [markdown]
# # Price

# %%
#SCRAPPING Price
cost = driver.find_elements_by_xpath("//div[@class='i-b tipsy fare-summary-tooltip fs-18']")
cost
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="cdb4da17-2ad0-4c97-b2a2-d3389edcc143")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="69c48b8b-f534-4ac5-93fd-f457f8fe1772")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="bb9d4698-e54d-4b23-9184-1c07d6a046cc")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="323f5fc6-6e87-4030-a281-191e5e3ad193")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="f7d2eff0-44a4-4f13-a680-41b4cf46b107")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="896cb00c-91d1-4b4c-8ff6-e7c3fd6b1e12")>,
# ...

# %%
# looping the Price
Price = []

for i in cost:
    Price.append(i.text)
Price
# Out:
# ['3,851',
#  '4,368',
#  '4,683',
#  '4,683',
#  '4,683',
#  '4,746',
#  '5,009',
#  '5,178',
#  '5,191',
#  '5,269',
#  '5,269',
#  '5,342',
#  '5,389',
#  '5,506',
#  '5,506',
#  '5,506',
#  '5,506',
#  '5,535',
#  '5,536',
#  '5,536',
#  '5,572',
#  '5,572',
#  '5,572',
#  '5,583',
#  '5,591',
#  '5,614',
#  '5,614',
#  '5,614',
#  '5,614',
#  '5,614',
#  '5,614',
#  '5,614',
#  '5,614',
#  '5,614',
#  '5,614',
#  '5,614',
#  '5,637',
#  '5,637',
#  '5,640',
#  '5,640',
#  '5,684',
#  '5,684',
#  '5,717',
#  '5,717',
#  '5,717',
#  '5,764',
#  '5,764',
#  '5,764',
#  '5,806',
#  '5,806',
#  '5,807',
#  '5,807',
#  '5,846',
#  '5,854',
#  '5,854',
#  '5,856',
#  '5,856',
#  '5,933',
#  '5,934',
#  '5,934',
#  '5,934',
#  '6,003',
#  '6,003',
#  '6,003',
#  '6,068',
#  '6,068',
#  '6,068',
#  '6,126',
#  '6,126',
#  '6,139',
#  '6,162',
#  '6,162',
#  '6,177',
#  '6,215',
#  '6,215',
#  '6,215',
#  '6,266',
#  '6,266',
#  '6,266',
#  '6,316',
#  '6,383',
#  '6,383',
#  '6,506',
# ...

# %%
# creating the dataframe for flight price prediction
df=pd.DataFrame({"Flight_name":Flight_name[0:],"Depart":Depart[0:],"Departure_Time":Departure_Time[0:],"Destination":Destination[0:],
                "Arrival_Time":Arrival_Time[0:],"Duration":Duration[0:],"Total_stops":Total_stops[0:],"Price":Price[0:]})
df
# Out:
#    Flight_name     Depart Departure_Time Destination    Arrival_Time Duration  \
# 0       IndiGo  Bangalore          06:20     Lucknow           08:55   2h 35m
# 1       IndiGo  Bangalore          17:55     Lucknow           20:25   2h 30m
# 2       IndiGo  Bangalore          06:35     Lucknow           13:20   6h 45m
# 3       IndiGo  Bangalore          13:15     Lucknow           20:10   6h 55m
# 4       IndiGo  Bangalore          11:45     Lucknow           20:10   8h 25m
# ..         ...        ...            ...         ...             ...      ...
# 94   Air India  Bangalore          19:10     Lucknow  16:35\n+ 1 day  21h 25m
# 95   Air India  Bangalore          06:10     Lucknow           16:35  10h 25m
# 96   Air India  Bangalore          19:10     Lucknow  16:35\n+ 1 day  21h 25m
# 97     Vistara  Bangalore          10:15     Lucknow  08:40\n+ 1 day  22h 25m
# 98     Vistara  Bangalore          12:20     Lucknow  08:40\n+ 1 day  20h 20m
#
#    Total_stops   Price
# ...

# %%
df.to_csv("flightprice11",index=False)

# %% [markdown]
# # Bangalore to Guwahati

# %%
url="https://flight.yatra.com/air-search-ui/seodom/trigger?type=O&viewName=normal&flexi=0&noOfSegments=1&origin=BLR&originCountry=IN&destination=GAU&preferred=&destinationCountry=IN&flight_depart_date=31%2F01%2F2022&ADT=1&CHD=0&INF=0&class=Economy&source=seo"

# %%
driver.get(url)

# %% [markdown]
# # airline name

# %%
# SCRAPPING airline_name
airline_name = driver.find_elements_by_xpath("//span[@class='i-b text ellipsis']")
airline_name
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="8976d25b-f593-483b-9afc-a17411a4dfec")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="92dc0572-51e9-420a-88aa-860bfd8d8e2c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="287a1682-c540-4801-b272-5ad68ef9f1a5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="d8cca6ac-1a51-416a-88cc-b78385a073d6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="dfe7f87d-e22f-410c-90c0-3b1a9a677081")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="26a1c1b6-1b82-4ae6-b473-3461d7207db0")>,
# ...

# %%
# looping the airline_name
Flight_name = []

for i in airline_name:
    Flight_name.append(i.text)
Flight_name
# Out:
# ['Vistara',
#  'Air Asia',
#  'Air Asia',
#  'IndiGo',
#  'Air Asia',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air Asia',
#  'Air India',
#  'Air India',
#  'Air India',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'Go First',
#  'Go First',
#  'Air Asia',
#  'Air Asia',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'SpiceJet',
#  'Air India',
#  'Air India',
#  'IndiGo',
#  'Air Asia',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'IndiGo',
#  'Air India',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
# ...

# %% [markdown]
# # departure

# %%
#SCRAPPING departure
source = driver.find_elements_by_xpath("//p[@title='Bangalore']")
source
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="9bce3ae8-7c29-4b03-a538-e927d36f9ee3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="5cced72c-9fe7-42a5-a81a-902d5affce63")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="0c7a590e-51d7-40f6-8cc2-3d96be2c4654")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="5301c68b-7667-417f-8ca6-0877fe6c2706")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="a23536f0-38b3-49ae-84a3-9b57ac71369b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="5dbc8f06-5500-4576-ba5d-9c0017cd007a")>,
# ...

# %%
# looping the departure
Depart = []

for i in source:
    Depart.append(i.text)
Depart
# Out:
# ['Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
# ...

# %% [markdown]
# # destination

# %%
#SCRAPPING destination
destiny = driver.find_elements_by_xpath("//p[@title='Guwahati']")
destiny
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="72f9f6cc-84e0-4d33-9387-59cf3297a4b0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="4ba21159-ce7f-4150-828e-d69c9e18976c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="9b55037d-80ad-4b16-98b4-56d72a8ef5f8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="fbf48d49-4ef7-4d27-a1b7-fd01607ffd32")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="8704b24d-3cac-40da-b18b-96ea44e87a45")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="45348198-d24d-43c5-a760-8ac8e99c5b20")>,
# ...

# %%
# looping the destination
Destination = []

for i in destiny:
    Destination.append(i.text)
Destination
# Out:
# ['Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
# ...

# %% [markdown]
# # departure time

# %%
#SCRAPPING departure time
Dept_Time = driver.find_elements_by_xpath("//div[@class='i-b pr']")
Dept_Time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="9c908d28-9c81-4c6a-81ae-887b1e782ce6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="6de7a6d7-ceed-4b21-970d-74ae161112dc")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="54ac64ac-998b-417e-95ab-83fecba10200")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="fea8622e-79fa-4578-be17-0444bf047ed7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="c5907583-2e47-4c86-be16-fcfa77f2284d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="f01c85d2-bfce-4498-91d5-00371395c6aa")>,
# ...

# %%
# looping the departure time
Departure_Time = []

for i in Dept_Time:
    Departure_Time.append(i.text)
Departure_Time
# Out:
# ['13:50',
#  '17:30',
#  '15:15',
#  '07:10',
#  '05:30',
#  '06:10',
#  '07:50',
#  '11:55',
#  '06:40',
#  '09:30',
#  '23:35',
#  '07:50',
#  '04:40',
#  '09:30',
#  '16:15',
#  '11:05',
#  '07:35',
#  '07:35',
#  '05:15',
#  '05:15',
#  '10:45',
#  '19:25',
#  '05:15',
#  '18:10',
#  '19:25',
#  '18:10',
#  '20:00',
#  '20:00',
#  '23:10',
#  '22:55',
#  '15:15',
#  '23:25',
#  '13:15',
#  '08:40',
#  '23:25',
#  '21:45',
#  '11:45',
#  '21:45',
#  '06:35',
#  '20:05',
#  '18:50',
#  '15:15',
#  '18:50',
#  '15:15',
#  '22:05',
#  '06:35',
#  '03:30',
#  '10:45',
#  '11:05',
#  '11:05',
#  '08:00',
#  '07:15',
#  '15:15',
#  '13:15',
#  '11:45',
#  '10:25',
#  '06:10',
#  '21:00',
#  '17:50',
#  '13:20',
#  '10:25',
#  '16:50',
#  '07:35',
#  '00:45',
#  '00:10',
#  '00:45',
#  '06:15',
#  '00:10',
#  '11:20',
#  '07:40',
#  '11:30',
#  '09:45',
#  '08:00',
#  '07:00',
#  '18:50',
#  '15:15',
#  '08:30',
#  '06:40',
#  '06:40',
#  '10:55',
#  '09:10',
#  '22:55',
#  '10:45',
# ...

# %% [markdown]
# # arrival time

# %%
#SCRAPPING arrival time
Arr_Time = driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
Arr_Time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="9ddfa5bb-fa32-4f5f-a674-4f26d088cf6c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="8d1190f3-214a-4862-a076-ca64f158235e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="01eed9e2-ca33-4795-a895-5e6b2d275703")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="fe8efd9c-003e-4974-871a-e33f5308f068")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="062cef4d-1cf8-4108-8e18-391b849d24b5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="d69c89b9-906c-47a7-8382-bf361a56b4ed")>,
# ...

# %%
# looping the arrival time
Arrival_Time = []

for i in Arr_Time:
    Arrival_Time.append(i.text)
Arrival_Time
# Out:
# ['17:00',
#  '20:40',
#  '18:30',
#  '11:45',
#  '10:20',
#  '11:45',
#  '14:55',
#  '19:55',
#  '14:55',
#  '17:50',
#  '09:30\n+ 1 day',
#  '17:50',
#  '14:55',
#  '19:55',
#  '20:55',
#  '11:05\n+ 1 day',
#  '11:05\n+ 1 day',
#  '18:10\n+ 1 day',
#  '10:45',
#  '14:55',
#  '21:00',
#  '10:45\n+ 1 day',
#  '21:00',
#  '10:45\n+ 1 day',
#  '14:55\n+ 1 day',
#  '14:55\n+ 1 day',
#  '07:30\n+ 1 day',
#  '10:30\n+ 1 day',
#  '06:40\n+ 1 day',
#  '06:40\n+ 1 day',
#  '20:05',
#  '05:55\n+ 1 day',
#  '20:05',
#  '16:15',
#  '07:00\n+ 1 day',
#  '05:55\n+ 1 day',
#  '20:05',
#  '07:00\n+ 1 day',
#  '16:15',
#  '05:55\n+ 1 day',
#  '11:05\n+ 1 day',
#  '11:05\n+ 1 day',
#  '18:10\n+ 1 day',
#  '18:10\n+ 1 day',
#  '01:10\n+ 1 day',
#  '11:40',
#  '11:40',
#  '14:55',
#  '07:35\n+ 1 day',
#  '09:15\n+ 1 day',
#  '10:55',
#  '10:15',
#  '22:10',
#  '22:10',
#  '22:10',
#  '18:45',
#  '18:45',
#  '12:10\n+ 1 day',
#  '12:10\n+ 1 day',
#  '12:10\n+ 1 day',
#  '12:10\n+ 1 day',
# ...

# %% [markdown]
# # duration

# %%
#SCRAPPING duration
Dur = driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
Dur
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="2a2974d2-de13-4421-bb78-e1b830dddadb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="ccef6167-f3aa-4954-b93f-87c7bfaa17fb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="a281d0a8-5eeb-471c-a2f4-0d52c3d728d0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="6623c01d-348d-41c3-ab53-78e046904804")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="ac7dfe13-5606-4edd-8f01-c66e416e5766")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="35a081cd-6da9-4a4c-b4ab-81af9de7af11")>,
# ...

# %%
# looping the duration
Duration = []

for i in Dur:
    Duration.append(i.text)
Duration
# Out:
# ['3h 10m',
#  '3h 10m',
#  '3h 15m',
#  '4h 35m',
#  '4h 50m',
#  '5h 35m',
#  '7h 05m',
#  '8h 00m',
#  '8h 15m',
#  '8h 20m',
#  '9h 55m',
#  '10h 00m',
#  '10h 15m',
#  '10h 25m',
#  '4h 40m',
#  '24h 00m',
#  '27h 30m',
#  '34h 35m',
#  '5h 30m',
#  '9h 40m',
#  '10h 15m',
#  '15h 20m',
#  '15h 45m',
#  '16h 35m',
#  '19h 30m',
#  '20h 45m',
#  '11h 30m',
#  '14h 30m',
#  '7h 30m',
#  '7h 45m',
#  '4h 50m',
#  '6h 30m',
#  '6h 50m',
#  '7h 35m',
#  '7h 35m',
#  '8h 10m',
#  '8h 20m',
#  '9h 15m',
#  '9h 40m',
#  '9h 50m',
#  '16h 15m',
#  '19h 50m',
#  '23h 20m',
#  '26h 55m',
#  '3h 05m',
#  '5h 05m',
#  '8h 10m',
#  '4h 10m',
#  '20h 30m',
#  '22h 10m',
#  '2h 55m',
#  '3h 00m',
#  '6h 55m',
#  '8h 55m',
#  '10h 25m',
#  '8h 20m',
#  '12h 35m',
#  '15h 10m',
#  '18h 20m',
#  '22h 50m',
#  '25h 45m',
#  '7h 25m',
#  '11h 10m',
#  '7h 30m',
#  '8h 05m',
#  '8h 40m',
#  '8h 55m',
#  '9h 15m',
#  '9h 50m',
#  '7h 40m',
#  '6h 00m',
#  '7h 45m',
#  '9h 30m',
#  '10h 30m',
# ...

# %% [markdown]
# # total stops

# %%
#SCRAPPING total stops
stops = driver.find_elements_by_xpath("//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']")
stops
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="3a9a96dd-7ca6-410c-b927-74a12cde53db")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="82b917dd-6128-40e0-9f7f-acff2a521ae6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="e9cc9341-9200-4538-a832-735dee9cb8a8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="a6263119-a661-4569-8d88-6bc5e3d583df")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="66a8ad70-73f2-48f7-8463-6b2ddf4a2443")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="88398ff5-f938-43f2-83ab-0ee571ff1a82")>,
# ...

# %%
# looping the total stops
Total_stops = []

for i in stops:
    Total_stops.append(i.text)
Total_stops
# Out:
# ['Non Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '3 Stop(s)',
#  '2 Stop(s)',
#  '3 Stop(s)',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
# ...

# %% [markdown]
# # Price

# %%
#SCRAPPING Price
cost = driver.find_elements_by_xpath("//div[@class='i-b tipsy fare-summary-tooltip fs-18']")
cost
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="b038a7fc-a761-4652-81af-4a5f8f71eb81")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="74b79c9b-af80-4813-b50e-2456cf161ee9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="98a1b21c-cffb-4b06-b8c7-93a5e6ef8f18")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="3b0629f1-c701-4fff-8fb4-1d40e404dbdd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="1bd4a24b-1f05-4d2d-a0b6-9a76b7aacffc")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="461f8af7668a64c59655da1d4bad8efe", element="c5604724-8060-4d58-a734-3576290af912")>,
# ...

# %%
# looping the Price
Price = []

for i in cost:
    Price.append(i.text)
Price
# Out:
# ['4,294',
#  '4,294',
#  '4,294',
#  '4,294',
#  '4,294',
#  '4,294',
#  '4,294',
#  '4,294',
#  '4,294',
#  '4,294',
#  '4,294',
#  '4,294',
#  '4,294',
#  '4,294',
#  '4,384',
#  '4,623',
#  '4,704',
#  '4,704',
#  '4,718',
#  '4,718',
#  '4,718',
#  '4,718',
#  '4,718',
#  '4,718',
#  '4,718',
#  '4,718',
#  '4,720',
#  '4,720',
#  '4,772',
#  '4,772',
#  '4,815',
#  '4,815',
#  '4,815',
#  '4,815',
#  '4,815',
#  '4,815',
#  '4,815',
#  '4,815',
#  '4,815',
#  '4,815',
#  '4,914',
#  '4,914',
#  '4,914',
#  '4,914',
#  '4,932',
#  '4,945',
#  '4,945',
#  '5,002',
#  '5,103',
#  '5,103',
#  '5,403',
#  '5,403',
#  '5,595',
#  '5,595',
#  '5,595',
#  '5,702',
#  '5,702',
#  '5,702',
#  '5,702',
#  '5,702',
#  '5,702',
#  '5,900',
#  '6,121',
#  '6,481',
#  '6,481',
#  '6,481',
#  '6,481',
#  '6,481',
#  '6,481',
#  '6,696',
#  '6,793',
#  '6,793',
#  '6,793',
#  '6,793',
#  '7,034',
#  '7,034',
#  '7,174',
#  '7,174',
#  '7,174',
#  '7,506',
#  '7,506',
#  '7,506',
#  '7,556',
# ...

# %%
# creating the dataframe for flight price prediction
df=pd.DataFrame({"Flight_name":Flight_name[0:],"Depart":Depart[0:],"Departure_Time":Departure_Time[0:],"Destination":Destination[0:],
                "Arrival_Time":Arrival_Time[0:],"Duration":Duration[0:],"Total_stops":Total_stops[0:],"Price":Price[0:]})
df
# Out:
#     Flight_name     Depart Departure_Time Destination    Arrival_Time  \
# 0       Vistara  Bangalore          13:50    Guwahati           17:00
# 1      Air Asia  Bangalore          17:30    Guwahati           20:40
# 2      Air Asia  Bangalore          15:15    Guwahati           18:30
# 3        IndiGo  Bangalore          07:10    Guwahati           11:45
# 4      Air Asia  Bangalore          05:30    Guwahati           10:20
# ..          ...        ...            ...         ...             ...
# 103     Vistara  Bangalore          19:25    Guwahati  12:05\n+ 1 day
# 104     Vistara  Bangalore          19:25    Guwahati  17:30\n+ 1 day
# 105     Vistara  Bangalore          19:25    Guwahati  17:30\n+ 1 day
# 106     Vistara  Bangalore          21:40    Guwahati  12:05\n+ 1 day
# 107     Vistara  Bangalore          12:20    Guwahati  12:05\n+ 1 day
#
#     Duration Total_stops   Price
# 0     3h 10m    Non Stop   4,294
# 1     3h 10m    Non Stop   4,294
# ...

# %%
df.to_csv("flightprice12",index=False)

# %% [markdown]
# # Kolkata to Delhi

# %%
url="https://flight.yatra.com/air-search-ui/seodom/trigger?type=O&viewName=normal&flexi=0&noOfSegments=1&origin=CCU&originCountry=IN&destination=DEL&preferred=&destinationCountry=IN&flight_depart_date=31%2F01%2F2022&ADT=1&CHD=0&INF=0&class=Economy&source=seo"

# %%
driver.get(url)

# %% [markdown]
# # airline name

# %%
# SCRAPPING airline_name
airline_name = driver.find_elements_by_xpath("//span[@class='i-b text ellipsis']")
airline_name
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4f186e4b4699876585dc3303def0c84a", element="2f1a6217-2948-45c8-a0ed-78aa944ed51a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4f186e4b4699876585dc3303def0c84a", element="0b8db271-8715-43fe-b07d-efa8bd10bcb2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4f186e4b4699876585dc3303def0c84a", element="1a8f0821-d8c5-40db-ad2e-dc13623d8415")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4f186e4b4699876585dc3303def0c84a", element="20270baf-f4e5-41cf-9e1a-69477ca15044")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4f186e4b4699876585dc3303def0c84a", element="d311257c-3795-4a23-8a90-31f98fe69555")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4f186e4b4699876585dc3303def0c84a", element="eeda1c8c-b586-4af0-af2d-d6389712dbd3")>,
# ...

# %%
# looping the airline_name
Flight_name = []

for i in airline_name:
    Flight_name.append(i.text)
Flight_name
# Out:
# ['Air India',
#  'Air India',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'SpiceJet',
#  'SpiceJet',
#  'Air Asia',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Go First',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air Asia',
#  'IndiGo',
#  'IndiGo',
#  'Go First',
#  'SpiceJet',
#  'SpiceJet',
#  'Air Asia',
#  'SpiceJet',
#  'SpiceJet',
#  'Air India',
#  'Air India',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'IndiGo',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air Asia',
#  'Air Asia',
#  'Go First',
#  'Air India',
#  'Air India',
#  'Go First',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air Asia',
#  'Air Asia',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'Go First',
#  'Air India',
# ...

# %% [markdown]
# # departure

# %%
#SCRAPPING departure
source = driver.find_elements_by_xpath("//p[@title='Kolkata']")
source
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4f186e4b4699876585dc3303def0c84a", element="8f243ec7-6eea-4b68-823e-80c55593ee96")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4f186e4b4699876585dc3303def0c84a", element="017951c1-2a52-45c8-bbb7-07732dff6ecf")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4f186e4b4699876585dc3303def0c84a", element="9a745bb8-7d88-4dc0-976d-f00513710d04")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4f186e4b4699876585dc3303def0c84a", element="4de500c3-20ad-42d1-88c1-c580607b27fe")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4f186e4b4699876585dc3303def0c84a", element="f2274d54-cf26-4402-ac55-aebc8612d3b8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4f186e4b4699876585dc3303def0c84a", element="0d93ef7c-97a6-460b-8ff7-2d2209448bf3")>,
# ...

# %%
# looping the departure
Depart = []

for i in source:
    Depart.append(i.text)
Depart
# Out:
# ['Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
# ...

# %% [markdown]
# # destination

# %%
#SCRAPPING destination
destiny = driver.find_elements_by_xpath("//p[@title='New Delhi']")
destiny
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4f186e4b4699876585dc3303def0c84a", element="cea38e0f-caad-44b1-8112-03e39acb755f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4f186e4b4699876585dc3303def0c84a", element="8dc106da-5d77-4412-ad73-aed0b544b92a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4f186e4b4699876585dc3303def0c84a", element="b6472670-34b7-4793-a4a3-11ecb93892ff")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4f186e4b4699876585dc3303def0c84a", element="c195b01d-7aa2-4b99-b6c9-640a30db5134")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4f186e4b4699876585dc3303def0c84a", element="1bd0eac8-f73d-409b-8df2-0f5199f1497f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4f186e4b4699876585dc3303def0c84a", element="29701343-87f4-40d1-aaa0-dd24855b041f")>,
# ...

# %%
# looping the destination
Destination = []

for i in destiny:
    Destination.append(i.text)
Destination
# Out:
# ['New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
# ...

# %% [markdown]
# # departure time

# %%
#SCRAPPING departure time
Dept_Time = driver.find_elements_by_xpath("//div[@class='i-b pr']")
Dept_Time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4f186e4b4699876585dc3303def0c84a", element="d8032761-8bf2-4bbc-958a-e32aa2498daa")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4f186e4b4699876585dc3303def0c84a", element="2ab8f72a-45d6-4e15-a2bd-0c247fd76b68")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4f186e4b4699876585dc3303def0c84a", element="b55a29f5-b435-4f2c-9149-d0ef5fb27803")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4f186e4b4699876585dc3303def0c84a", element="64c9bca9-e82f-43b8-8513-9d8cd4b20e0d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4f186e4b4699876585dc3303def0c84a", element="8cbac6e1-488b-4e28-9f2e-1b3090680a5e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4f186e4b4699876585dc3303def0c84a", element="c988f2b7-c990-4d66-be3a-270e54fa9c0b")>,
# ...

# %%
# looping the departure time
Departure_Time = []

for i in Dept_Time:
    Departure_Time.append(i.text)
Departure_Time
# Out:
# ['07:00',
#  '10:25',
#  '15:30',
#  '14:15',
#  '14:15',
#  '11:10',
#  '11:10',
#  '18:40',
#  '13:10',
#  '07:40',
#  '11:25',
#  '01:15',
#  '05:30',
#  '06:00',
#  '08:45',
#  '16:30',
#  '18:05',
#  '19:20',
#  '20:25',
#  '21:40',
#  '23:40',
#  '06:40',
#  '10:05',
#  '14:20',
#  '15:45',
#  '07:35',
#  '19:45',
#  '20:50',
#  '09:05',
#  '19:00',
#  '19:00',
#  '10:15',
#  '07:10',
#  '15:20',
#  '20:20',
#  '12:00',
#  '12:00',
#  '19:00',
#  '20:30',
#  '07:15',
#  '17:15',
#  '17:15',
#  '17:15',
#  '12:00',
#  '05:25',
#  '05:25',
#  '09:20',
#  '09:50',
#  '09:50',
#  '09:20',
#  '11:35',
#  '11:35',
#  '07:45',
#  '05:55',
#  '07:45',
#  '05:55',
#  '11:35',
#  '09:05',
#  '09:05',
#  '06:00',
#  '06:00',
#  '06:00',
#  '18:05',
#  '18:05',
#  '18:05',
#  '16:25',
#  '09:40',
#  '09:40',
#  '09:40',
#  '09:40',
#  '09:40',
#  '18:10',
#  '09:55',
#  '04:55',
#  '17:30',
#  '17:30',
#  '04:55',
#  '04:55',
#  '12:00',
#  '12:00',
#  '17:30',
#  '17:30',
#  '14:45',
# ...

# %% [markdown]
# # arrival time

# %%
#SCRAPPING arrival time
Arr_Time = driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
Arr_Time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4f186e4b4699876585dc3303def0c84a", element="c15b28c9-125d-4092-807a-b74631158c2f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4f186e4b4699876585dc3303def0c84a", element="fbabb5a1-3069-40bf-9c59-b51c6cd6c5a0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4f186e4b4699876585dc3303def0c84a", element="ce71047e-68a3-41f2-8d9e-c7b689045ee1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4f186e4b4699876585dc3303def0c84a", element="739f29f2-68a7-414a-8c52-d4454f07bddf")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4f186e4b4699876585dc3303def0c84a", element="38479326-e0f7-4970-b9b3-bf509259a92e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4f186e4b4699876585dc3303def0c84a", element="31c7fc46-c49b-4a01-9cf5-6c6433b126ac")>,
# ...

# %%
# looping the arrival time
Arrival_Time = []

for i in Arr_Time:
    Arrival_Time.append(i.text)
Arrival_Time
# Out:
# ['09:15',
#  '12:55',
#  '18:00',
#  '20:25',
#  '22:35',
#  '20:25',
#  '22:35',
#  '20:50',
#  '15:30',
#  '10:05',
#  '13:50',
#  '03:45',
#  '08:00',
#  '08:30',
#  '11:15',
#  '19:00',
#  '20:35',
#  '21:50',
#  '22:55',
#  '00:10\n+ 1 day',
#  '02:10\n+ 1 day',
#  '09:15',
#  '12:40',
#  '16:55',
#  '18:20',
#  '10:15',
#  '22:25',
#  '23:30',
#  '11:50',
#  '13:50\n+ 1 day',
#  '18:30\n+ 1 day',
#  '12:35',
#  '09:35',
#  '17:45',
#  '22:45',
#  '23:15',
#  '16:15\n+ 1 day',
#  '08:55\n+ 1 day',
#  '22:45',
#  '15:25',
#  '08:55\n+ 1 day',
#  '13:00\n+ 1 day',
#  '19:50\n+ 1 day',
#  '23:45',
#  '11:50',
#  '15:30',
#  '18:55',
#  '18:40',
#  '22:05',
#  '18:15',
#  '23:15',
#  '16:15\n+ 1 day',
#  '18:40',
#  '18:40',
#  '22:05',
#  '22:05',
#  '23:45',
#  '14:55',
#  '19:20',
#  '11:15',
#  '17:15',
#  '19:45',
#  '11:15\n+ 1 day',
#  '17:15\n+ 1 day',
#  '19:45\n+ 1 day',
#  '23:30',
#  '19:20',
#  '20:30',
#  '21:15',
#  '23:30',
#  '08:55\n+ 1 day',
#  '11:50\n+ 1 day',
# ...

# %% [markdown]
# # duration

# %%
#SCRAPPING duration
Dur = driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
Dur
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4f186e4b4699876585dc3303def0c84a", element="29040618-ec1f-4324-9b14-40ed50b80c58")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4f186e4b4699876585dc3303def0c84a", element="24296347-18f8-4dcb-9f2d-51c5773715ef")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4f186e4b4699876585dc3303def0c84a", element="ee53ce1b-aa28-4110-b8a2-2721d08ce26a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4f186e4b4699876585dc3303def0c84a", element="bf458bcc-3523-42b2-9442-bdd8ed602ca5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4f186e4b4699876585dc3303def0c84a", element="72bdfd45-695d-4ef0-b65c-5bf1fbab466a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4f186e4b4699876585dc3303def0c84a", element="33e2be67-fd4a-4ac5-a246-ea968e0224eb")>,
# ...

# %%
# looping the duration
Duration = []

for i in Dur:
    Duration.append(i.text)
Duration
# Out:
# ['2h 15m',
#  '2h 30m',
#  '2h 30m',
#  '6h 10m',
#  '8h 20m',
#  '9h 15m',
#  '11h 25m',
#  '2h 10m',
#  '2h 20m',
#  '2h 25m',
#  '2h 25m',
#  '2h 30m',
#  '2h 30m',
#  '2h 30m',
#  '2h 30m',
#  '2h 30m',
#  '2h 30m',
#  '2h 30m',
#  '2h 30m',
#  '2h 30m',
#  '2h 30m',
#  '2h 35m',
#  '2h 35m',
#  '2h 35m',
#  '2h 35m',
#  '2h 40m',
#  '2h 40m',
#  '2h 40m',
#  '2h 45m',
#  '18h 50m',
#  '23h 30m',
#  '2h 20m',
#  '2h 25m',
#  '2h 25m',
#  '2h 25m',
#  '11h 15m',
#  '28h 15m',
#  '13h 55m',
#  '2h 15m',
#  '8h 10m',
#  '15h 40m',
#  '19h 45m',
#  '26h 35m',
#  '11h 45m',
#  '6h 25m',
#  '10h 05m',
#  '9h 35m',
#  '8h 50m',
#  '12h 15m',
#  '8h 55m',
#  '11h 40m',
#  '28h 40m',
#  '10h 55m',
#  '12h 45m',
#  '14h 20m',
#  '16h 10m',
#  '12h 10m',
#  '5h 50m',
#  '10h 15m',
#  '5h 15m',
#  '11h 15m',
#  '13h 45m',
#  '17h 10m',
#  '23h 10m',
#  '25h 40m',
#  '7h 05m',
#  '9h 40m',
#  '10h 50m',
#  '11h 35m',
#  '13h 50m',
#  '23h 15m',
#  '17h 40m',
#  '25h 55m',
#  '7h 15m',
# ...

# %% [markdown]
# # total stops

# %%
#SCRAPPING total stops
stops = driver.find_elements_by_xpath("//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']")
stops
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4f186e4b4699876585dc3303def0c84a", element="b5e612c1-2677-4a7b-9e40-3ffe6a2f6c24")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4f186e4b4699876585dc3303def0c84a", element="c899d651-3f3e-43a0-8ecf-260aa5c7bd65")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4f186e4b4699876585dc3303def0c84a", element="406ee922-c4d1-4941-9335-b9f93cb6d181")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4f186e4b4699876585dc3303def0c84a", element="8b0d517a-04c7-45a8-b3a4-d694c9304b4b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4f186e4b4699876585dc3303def0c84a", element="9a952bf9-7b56-43d2-a45f-3930e2384343")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4f186e4b4699876585dc3303def0c84a", element="3353b75b-81b6-4b65-8152-9e3a09a27b1b")>,
# ...

# %%
# looping the total stops
Total_stops = []

for i in stops:
    Total_stops.append(i.text)
Total_stops
# Out:
# ['Non Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  '3 Stop(s)',
#  '2 Stop(s)',
#  '1 Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '3 Stop(s)',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
# ...

# %% [markdown]
# # Price

# %%
#SCRAPPING Price
cost = driver.find_elements_by_xpath("//div[@class='i-b tipsy fare-summary-tooltip fs-18']")
cost
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4f186e4b4699876585dc3303def0c84a", element="0910817c-20b7-4dd0-9128-55a407f504b0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4f186e4b4699876585dc3303def0c84a", element="ef954e9b-67f4-40f8-bf37-c28ac9299f15")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4f186e4b4699876585dc3303def0c84a", element="fcd0bbde-2c4e-4999-aa07-4876d42c204c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4f186e4b4699876585dc3303def0c84a", element="0d3f53cb-aa91-474d-94f9-1fe71978442c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4f186e4b4699876585dc3303def0c84a", element="96f42ecd-b06e-4481-985e-2bc22235ca25")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4f186e4b4699876585dc3303def0c84a", element="4ec686f7-e1cb-4ccb-8df1-7e692c20e258")>,
# ...

# %%
# looping the Price
Price = []

for i in cost:
    Price.append(i.text)
Price
# Out:
# ['3,016',
#  '3,016',
#  '3,016',
#  '3,016',
#  '3,016',
#  '3,016',
#  '3,016',
#  '3,999',
#  '3,999',
#  '3,999',
#  '3,999',
#  '3,999',
#  '3,999',
#  '3,999',
#  '3,999',
#  '3,999',
#  '3,999',
#  '3,999',
#  '3,999',
#  '3,999',
#  '3,999',
#  '3,999',
#  '3,999',
#  '3,999',
#  '3,999',
#  '3,999',
#  '3,999',
#  '3,999',
#  '3,999',
#  '4,144',
#  '4,144',
#  '4,200',
#  '4,200',
#  '4,200',
#  '4,200',
#  '4,505',
#  '4,505',
#  '4,564',
#  '4,631',
#  '4,740',
#  '4,919',
#  '4,919',
#  '4,919',
#  '4,925',
#  '4,945',
#  '4,945',
#  '5,007',
#  '5,093',
#  '5,093',
#  '5,232',
#  '5,408',
#  '5,408',
#  '5,597',
#  '5,597',
#  '5,597',
#  '5,597',
#  '5,828',
#  '5,934',
#  '5,934',
#  '5,959',
#  '5,959',
#  '5,959',
#  '5,959',
#  '5,959',
#  '5,959',
#  '6,117',
#  '6,339',
#  '6,339',
#  '6,339',
#  '6,339',
#  '6,339',
#  '6,354',
#  '6,354',
#  '6,448',
#  '6,448',
#  '6,448',
#  '6,448',
#  '6,448',
#  '6,464',
#  '6,464',
#  '6,483',
#  '6,483',
#  '6,483',
# ...

# %%
# creating the dataframe for flight price prediction
df=pd.DataFrame({"Flight_name":Flight_name[0:],"Depart":Depart[0:],"Departure_Time":Departure_Time[0:],"Destination":Destination[0:],
                "Arrival_Time":Arrival_Time[0:],"Duration":Duration[0:],"Total_stops":Total_stops[0:],"Price":Price[0:]})
df
# Out:
#     Flight_name   Depart Departure_Time Destination    Arrival_Time Duration  \
# 0     Air India  Kolkata          07:00   New Delhi           09:15   2h 15m
# 1     Air India  Kolkata          10:25   New Delhi           12:55   2h 30m
# 2     Air India  Kolkata          15:30   New Delhi           18:00   2h 30m
# 3        IndiGo  Kolkata          14:15   New Delhi           20:25   6h 10m
# 4        IndiGo  Kolkata          14:15   New Delhi           22:35   8h 20m
# ..          ...      ...            ...         ...             ...      ...
# 142     Vistara  Kolkata          10:25   New Delhi  19:55\n+ 1 day  33h 30m
# 143   Air India  Kolkata          05:30   New Delhi           14:35   9h 05m
# 144     Vistara  Kolkata          17:35   New Delhi  12:30\n+ 1 day  18h 55m
# 145     Vistara  Kolkata          10:25   New Delhi  09:00\n+ 1 day  22h 35m
# 146     Vistara  Kolkata          17:35   New Delhi  19:50\n+ 1 day  26h 15m
#
#     Total_stops   Price
# ...

# %%
df.to_csv("flightprice13",index=False)
